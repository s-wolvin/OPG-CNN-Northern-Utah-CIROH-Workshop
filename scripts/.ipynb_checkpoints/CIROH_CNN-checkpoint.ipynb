# %% [markdown]
# # CIROH Developers Conference: Hydrological Applications of ML
# ### CNNs for Predicting Daily Orographic Precipitation Gradients (OPGs) for Atmospheric Downscaling

# %% [markdown]
# ## Introduction
#
# In this exercise, we'll build a convolutional neural network (CNN) for regression of orographic precipitation gradients of Northern Utah. Other uses include:
#
# - Image classification
# - Image denoising or reconstruction
#
# But all methods are based around two basic operations:
#
# - Convolution: in this step, the network learns a series of kernels or filters that transform the original image in some way. These are similar to filters that are used in standard image processing (e.g. low-pass filters), but filters are chosen by how well the transformed image maps to the outcome variable. To put this another way, these filters identify shapes or features that are important in differentiating between different outcomes
# - Max-pooling: in this step, the image resolution is transformed. In general, the resolution is halved, by aggregating groups of four pixels in a two by two window.
#
# In general, these steps are repeated several times. As this progresses, the small shapes identified in the first set of convolutions are progressively combined into larger structures. For example, a series of small curves or lines could be aggregated into a cat's eye.

# %% [markdown]
# ## Data processing
# ##### Let's start, as usual, by loading the libraries we'll need for the lab:

# %%
# Data manipulation
import pandas as pd
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt
from matplotlib import colors
import nclcmaps as ncm

# %% [markdown]
# ##### Now we set the path to the data folders and download the datasets. If you have any questions about setting this path, please ask.

# %%
# load in the atmospheric data
path      = "../datasets/era5_atmos/"
IVT       = xr.open_dataset(f"{path}IVT_sfc.nc")
precip    = xr.open_dataset(f"{path}precip_sfc.nc")*1000
temp700   = xr.open_dataset(f"{path}temp_700.nc")-273.15
uwinds700 = xr.open_dataset(f"{path}uwnd_700.nc")
vwinds700 = xr.open_dataset(f"{path}vwnd_700.nc")
hgt500    = xr.open_dataset(f"{path}hgt_500.nc")/9.81

# load in the OPGs
path = "../datasets/facets_and_opgs/"
opg  = pd.read_csv(f"{path}winter_northernUT_opg.csv", index_col=0)
facet_list = opg.columns.values
opg = opg.values

# %% [markdown]
# #### Standardizing the Datasets:
#
# ##### Since the values between the atmospheric variables contain a large variability in scale, we standardize each variable individually. This levels the playing field, so to speak, so that all atmospheric variables are taken into account within the CNN. This also applies to the facet OPGs, as a machine learning model is better equipted predicting values between -1 and 1.
#
# ##### In other cases, you may prefer to normalize the datasets.

# %%
IVT       = (IVT - IVT.mean(dim="time")) / IVT.std(dim="time")
precip    = (precip - precip.mean(dim="time")) / precip.std(dim="time")
temp700   = (temp700 - temp700.mean(dim="time")) / temp700.std(dim="time")
uwinds700 = (uwinds700 - uwinds700.mean(dim="time")) / uwinds700.std(dim="time")
vwinds700 = (vwinds700 - vwinds700.mean(dim="time")) / vwinds700.std(dim="time")
hgt500    = (hgt500 - hgt500.mean(dim="time")) / hgt500.std(dim="time")

opg_mean = np.nanmean(opg, axis=0) # Save OPG mean and standard deviation so that we can
opg_std  = np.nanstd(opg, axis=0)  # convert back to true values from standardized values later on.
opg = (opg - opg_mean) / opg_std

# %% [markdown]
# ##### Unique to the OPG dataset, for days without precipitation, the value within the array are NaNs. However, machine learning algoirthms of this architecture are unable to predict NaN as an output. Therefore, days without observations are set to zero, as it is the average value of the dataset.
#
# ##### In classification tasks, the missing values are often set to a new catagory.

# %%
opg[np.isnan(opg)] = 0

# %% [markdown]
# ##### To input the atmospheric data into the CNN model, the atmospheric variables are combined into one array.

# %%
# Combine the atmospheric data into one array
atmos = np.concatenate((IVT.IVT.values[...,np.newaxis], 
                        precip.precip.values[...,np.newaxis],
                        temp700.temp.values[...,np.newaxis],
                        uwinds700.uwnd.values[...,np.newaxis],
                        vwinds700.vwnd.values[...,np.newaxis],
                        hgt500.hgt.values[...,np.newaxis]), axis=3)
print(np.shape(atmos))
# Out:
# (2708, 19, 27, 6)

# %% [markdown]
# ##### The above output lists the dimensions of all the atmospheric variables combined. It contains 2708 observation days or 'images', with a 19 x 27 grid of latitudes and longitudes. Each atmospheric variable represents a channel, here we have 6 channels.
#
# ##### Channels can be viewed as layers of the image. For example, when using visual images of RGB colors, there would be 3 channels.
#
# ##### CNNs are not limited only to images of shape `(samples, height, width, channels)`, CNNs can be used to evaluate vector data `(samples, features)`, timeseries data `(samples, timesteps, features)`, and video data `(samples, frames, height, width, channels)`.

# %%
latitude  = 19 # height
longitude = 27 # width
channels  = 6  # channel

# %% [markdown]
# ##### When creating a ML model, the datasets are split into training, validation, and testing subsets. The model is trained on the training subset, evaluated on the validation subset, and tested on the testing subset.
#
# ##### These datasets are often randomly shuffled to produce training, validation, and testing subsets. If redundency exists in your dataset, or in our case, multipday precipitation events, it can be important to split the subsets differently. Such as by week, months, or years.
#
# ##### Here, we'll split these datasets at random using a 70/15/15% split.

# %%
np.random.seed(42)
rand_ind = np.random.permutation(np.arange(np.shape(atmos)[0]))

train_atmos = atmos[rand_ind[:1896], ...]
test_atmos  = atmos[rand_ind[1896:2302], ...]
val_atmos   = atmos[rand_ind[2302:], ...]

train_opg = opg[rand_ind[:1896], ...]
test_opg  = opg[rand_ind[1896:2302], ...]
val_opg   = opg[rand_ind[2302:], ...]

print(np.shape(test_atmos))
# Out:
# (406, 19, 27, 6)

# %% [markdown]
# ##### The last parameter we'll set here is the batch size. This parameter controls how many samples are processed in training simultaneously, typically between 8 and 128. The dataset is separated into batches, processed by the model, and the weights within the model are adjusted. Once all batches are processed, one epoch has been completed.
#
# ##### This also controls how much memory is used per step of training, which is very useful if you're training on a computer with limited memory.

# %%
batch_size = 32

# %% [markdown]
# ## Create CNN Model
#
# ##### Let's now set up the model. As this is quite a complex model, we'll do this as a series of steps rather than in one go. First, import all the modules from Keras that we'll need:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (InputLayer, 
                                      Conv2D,
                                      Dense,
                                      ReLU,LeakyReLU,
                                      BatchNormalization, 
                                      MaxPooling2D, 
                                      Dropout,
                                      Flatten)
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Now, create a template sequential model, this way we can build the model incrementally:

# %%
model = Sequential()

# %% [markdown]
# ##### First, we'll use `InputLayer` to declare the shape of the input data. Notice that we care about the entire input set, not the batch size.

# %%
model.add(InputLayer(shape=(latitude, longitude, channels)))

# %% [markdown]
# ##### Next we add the first hidden layer, `Conv2D`. This is a convolutional layer, where we'll create 16 filters (or convolutions) based on the original images, with a 3x3 kernel. We'll add padding to the input of the `Conv2D` layer, this adds the appropriate number of rows and columns around the input image so that the output image is the `same` height and width.

# %%
model.add(Conv2D(filters = 16, kernel_size = (3,3), padding = 'same'))

# %% [markdown]
# ##### We'll then take the output of this layer and pass it through a `ReLU()` activation function (this could have been included directly in the convolutional layer, but this allows a little more control on the process):

# %%
model.add(ReLU())

# %% [markdown]
# ##### Now, we add a `MaxPooling2D` layer. As a reminder, this reduces the resolution of the output from the previous layer by a simple filter, forcing the next layer of the network to focus on larger image features. We'll also add a `Dropout` layer. This is a form of regularization. It randomly sets some connection weights to 0 (i.e. having no contribution to the model), which can reduce overfitting.

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Let's add another convolutional layer, this time with 32 filters, and pass this through a ReLU activation function.

# %%
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'same'))
model.add(ReLU())

# %% [markdown]
# ##### We'll take the output of this function and normalize the weights. This is a simple method that adjusts the mean weight to close to zero and reduces the amount of variation. This helps avoid gradient problems with very small or very large weights

# %%
model.add(BatchNormalization())

# %% [markdown]
# ##### And we'll run the output of this through a max-pooling function with dropout:

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Now we'll add layers to connect the output of this last `MaxPooling2D` step to the output (the OPGs). The first thing we need to do is to `Flatten()` the output. The output of the max-pooling is a tensor of shape (4, 6, 32). The size of 4x5 is a result of the two max-pooling operations and the 32 is the number of filters from the second convolution. The `Flatten()` function will flatten this into a rank 1 tensor of shape (768).

# %%
model.add(Flatten())

# %% [markdown]
# ##### Next we'll pass this flattened layer through a `Dense()` layer, which are densely conncted neural layers. And then through `ReLU()` activation and a dropout

# %%
model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dropout(.25))

# %% [markdown]
# ##### Finally, we need to output predictions. As this is a regression task, the final layer needs to have the same number of nodes as northern Utah facets, and the output is passed through a linear activation function. Linear activation functions are typically used whe you're trying to predict continuous values.

# %%
model.add(Dense(units = len(facet_list), activation = 'linear'))

# %% [markdown]
# ##### More practically, we'll create a function that will build the model in one go. This will allow us to easily create new versions for testing.

# %%
def create_model():
    model = Sequential([  
        InputLayer(shape=(latitude, longitude, channels)),
        Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu', name='Convolution_01'),
        MaxPooling2D(pool_size = (2,2), name='Max_Pooling_01'),
        Dropout(.25),
        Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu', name='Convolution_02'),
        BatchNormalization(name='Batch_Normalization'),
        MaxPooling2D(pool_size = (2,2), name='Max_Pooling_02'),
        Dropout(.25),
        Flatten(),
        Dense(units = 100, activation = 'relu', name='Hidden_Layer_01'),
        Dense(units = 100, activation = 'relu', name='Hidden_Layer_02'),
        Dropout(.25),
        Dense(units = len(facet_list), activation = 'linear', name='Output')
    ])
    return model

# %% [markdown]
# ##### Let's take a look at the whole thing:

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Convolution_01 (Conv2D)         │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Max_Pooling_01 (MaxPooling2D)   │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Convolution_02 (Conv2D)         │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Batch_Normalization             │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Max_Pooling_02 (MaxPooling2D)   │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_01 (Dense)         │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_02 (Dense)         │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)

# %% [markdown]
# ##### Our model has a little over 95,000 parameters or weights to train (hence the need for a lot of images). Note that there are small set of non-trainable parameter from the normalization layer.
#
# ##### We can also generate a simple visualization:

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True,dpi=75)

# %% [markdown]
# ##### The next step is to compile the model. This is an optimization function, a loss function and performance metric. A good option for the loss function in a regression problem is `mean_squared_error`, metrics allows the user to add aditional functions to monitor training. The optimizer implements the agorithmn which updates the weights of the model.

# %%
model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop())

# %% [markdown]
# ## Training the model
#
# ##### We'll now train the model for 50 epochs using the `fit()` method upon our built model. We specify:
#
# - `train_atmos`: The training subset of the atmospheric variables
# - `train_opg`: The training subset of the observed OPGs
# - `batch_size`: The number of samples or observation days used per gradient update.
# - `epochs`: The number of full training iterations.
# - `validation_data`: The validation subset of the atmospheric variables and observed OPGs
#
# ##### This takes a few minutes to train (on my laptop). It's worth remembering what is going on here: the algorithm is reading in batches of 32 images, rescaling them, updating model weights through back propagation and then repeating the whole thing 50 times. As we previously defined a separate validation subset, this routine will calculate two losses:
# - The training loss. This is how accurately the model can predict OPG from the atmospheric 'images' that are being used to update the weights
# - The validation loss. This is how accurately the model can predict OPG from a set of atmospheric 'images' that are not used in updating the weights
#
# ##### As the model continues to train, you should see the loss decrease for both of these, but will likely stabilize at a certain point.

# %%
epochs = 50
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.8665 - mean_absolute_error: 0.5849 - val_loss: 0.4763 - val_mean_absolute_error: 0.3392
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4217 - mean_absolute_error: 0.3538 - val_loss: 0.4473 - val_mean_absolute_error: 0.3278
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4008 - mean_absolute_error: 0.3384 - val_loss: 0.4187 - val_mean_absolute_error: 0.3347
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3934 - mean_absolute_error: 0.3390 - val_loss: 0.3919 - val_mean_absolute_error: 0.3194
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3766 - mean_absolute_error: 0.3296 - val_loss: 0.3868 - val_mean_absolute_error: 0.3258
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3612 - mean_absolute_error: 0.3194 - val_loss: 0.3672 - val_mean_absolute_error: 0.3222
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3484 - mean_absolute_error: 0.3191 - val_loss: 0.3676 - val_mean_absolute_error: 0.3177
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3477 - mean_absolute_error: 0.3121 - val_loss: 0.3717 - val_mean_absolute_error: 0.3147
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3482 - mean_absolute_error: 0.3118 - val_loss: 0.3630 - val_mean_absolute_error: 0.3158
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3557 - mean_absolute_error: 0.3167 - val_loss: 0.3664 - val_mean_absolute_error: 0.3237
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3332 - mean_absolute_error: 0.3081 - val_loss: 0.3645 - val_mean_absolute_error: 0.3219
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3178 - mean_absolute_error: 0.2999 - val_loss: 0.3612 - val_mean_absolute_error: 0.3164
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3136 - mean_absolute_error: 0.2977 - val_loss: 0.3512 - val_mean_absolute_error: 0.3131
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3005 - mean_absolute_error: 0.2934 - val_loss: 0.3720 - val_mean_absolute_error: 0.3354
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3130 - mean_absolute_error: 0.2944 - val_loss: 0.3564 - val_mean_absolute_error: 0.3208
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3215 - mean_absolute_error: 0.3034 - val_loss: 0.3835 - val_mean_absolute_error: 0.3342
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3113 - mean_absolute_error: 0.2970 - val_loss: 0.3599 - val_mean_absolute_error: 0.3222
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3191 - mean_absolute_error: 0.3046 - val_loss: 0.3722 - val_mean_absolute_error: 0.3261
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2913 - mean_absolute_error: 0.2961 - val_loss: 0.3548 - val_mean_absolute_error: 0.3166
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2986 - mean_absolute_error: 0.2919 - val_loss: 0.3407 - val_mean_absolute_error: 0.3166
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3125 - mean_absolute_error: 0.3006 - val_loss: 0.3516 - val_mean_absolute_error: 0.3148
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2993 - mean_absolute_error: 0.2916 - val_loss: 0.3491 - val_mean_absolute_error: 0.3107
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3023 - mean_absolute_error: 0.2965 - val_loss: 0.3567 - val_mean_absolute_error: 0.3233
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2843 - mean_absolute_error: 0.2874 - val_loss: 0.3551 - val_mean_absolute_error: 0.3174
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3115 - mean_absolute_error: 0.2988 - val_loss: 0.3612 - val_mean_absolute_error: 0.3196
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2993 - mean_absolute_error: 0.2961 - val_loss: 0.3502 - val_mean_absolute_error: 0.3138
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3076 - mean_absolute_error: 0.2991 - val_loss: 0.3639 - val_mean_absolute_error: 0.3279
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2801 - mean_absolute_error: 0.2857 - val_loss: 0.3521 - val_mean_absolute_error: 0.3213
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2843 - mean_absolute_error: 0.2872 - val_loss: 0.3613 - val_mean_absolute_error: 0.3279
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2839 - mean_absolute_error: 0.2880 - val_loss: 0.3646 - val_mean_absolute_error: 0.3271
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2623 - mean_absolute_error: 0.2784 - val_loss: 0.3610 - val_mean_absolute_error: 0.3239
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2763 - mean_absolute_error: 0.2859 - val_loss: 0.3540 - val_mean_absolute_error: 0.3187
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2809 - mean_absolute_error: 0.2868 - val_loss: 0.3457 - val_mean_absolute_error: 0.3112
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2711 - mean_absolute_error: 0.2825 - val_loss: 0.3559 - val_mean_absolute_error: 0.3165
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2588 - mean_absolute_error: 0.2758 - val_loss: 0.3563 - val_mean_absolute_error: 0.3207
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2993 - mean_absolute_error: 0.2936 - val_loss: 0.3511 - val_mean_absolute_error: 0.3171
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2780 - mean_absolute_error: 0.2899 - val_loss: 0.3520 - val_mean_absolute_error: 0.3133
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2604 - mean_absolute_error: 0.2773 - val_loss: 0.3551 - val_mean_absolute_error: 0.3227
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2702 - mean_absolute_error: 0.2839 - val_loss: 0.3587 - val_mean_absolute_error: 0.3190
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2773 - mean_absolute_error: 0.2848 - val_loss: 0.3521 - val_mean_absolute_error: 0.3155
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2624 - mean_absolute_error: 0.2816 - val_loss: 0.3546 - val_mean_absolute_error: 0.3197
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2717 - mean_absolute_error: 0.2864 - val_loss: 0.3612 - val_mean_absolute_error: 0.3206
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2710 - mean_absolute_error: 0.2801 - val_loss: 0.3546 - val_mean_absolute_error: 0.3161
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2530 - mean_absolute_error: 0.2756 - val_loss: 0.3540 - val_mean_absolute_error: 0.3114
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2691 - mean_absolute_error: 0.2848 - val_loss: 0.3504 - val_mean_absolute_error: 0.3111
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2542 - mean_absolute_error: 0.2767 - val_loss: 0.3604 - val_mean_absolute_error: 0.3159
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2418 - mean_absolute_error: 0.2708 - val_loss: 0.3536 - val_mean_absolute_error: 0.3174
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2500 - mean_absolute_error: 0.2758 - val_loss: 0.3582 - val_mean_absolute_error: 0.3154
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2529 - mean_absolute_error: 0.2727 - val_loss: 0.3450 - val_mean_absolute_error: 0.3088
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2538 - mean_absolute_error: 0.2724 - val_loss: 0.3577 - val_mean_absolute_error: 0.3145

# %% [markdown]
# ##### Now plot the evolution of the loss function and the actual versus predicted OPGs:

# %%
def plot_loss(hist_obs, name):
    # Define label sizes
    label_size = 14
    tick_size = 12
    
    # Create Figure
    plt.figure(figsize=(7, 4))
    plt.plot(hist_obs.history['loss'], label='train')
    plt.plot(hist_obs.history['val_loss'], label='valid')
    plt.xlabel("Epochs", fontsize=label_size)
    plt.ylabel("Mean Squared Error", fontsize=label_size)
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()

    # Save and show figure
    path = "../figures/"
    plt.savefig(f"{path}eval_loss_{name}.png", dpi=200, transparent=True,  bbox_inches='tight')
    plt.show()

def plot_act_pred(modelx, hist_obs, name):
    # Using our fitted model, predict OPGs from the testing subset.
    predicted = modelx.predict(test_atmos)

    # set zero OPGs to nan
    actual = test_opg
    actual[actual==0] = np.nan
    predicted[predicted==0] = np.nan
    
    # Convert from standardized OPG to mm/m OPG
    actual    = (test_opg * opg_std) + opg_mean
    predicted = (predicted * opg_std) + opg_mean
    
    # Lets reshape our OPGs and remove NaN OPG days
    actual    = np.reshape(actual, -1)
    predicted = np.reshape(predicted, -1)
    idx       = np.isnan(actual) # Identify days with OPG observations
    actual    = actual[idx==False]
    predicted = predicted[idx==False]
    
    # Formulate the x and y axis limits
    max_val = np.max((np.max(predicted[:]), np.max(actual[:])))
    min_val = np.min((np.min(predicted[:]), np.min(actual[:])))
    max_val = 0.05
    min_val = -0.05
    
    # Define plot colormap
    cmap_gnuplot2 = ncm.cmap("MPL_gnuplot2")
    
    # Define label sizes
    label_size = 14
    tick_size = 12
    
    # Create Figure
    plt.figure(figsize=(6, 5))
    
    # Formulate the heatmap variables
    heatmap, xedges, yedges = np.histogram2d(np.reshape(actual, -1), np.reshape(predicted, -1), bins=100,
                                 range=[[min_val, max_val],[min_val, max_val]])
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

    # Plot heatmap
    plt.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap_gnuplot2, norm=colors.LogNorm())

    # Plot One-to-one line
    plt.plot([xedges[0], xedges[-1]], [yedges[0], yedges[-1]], c='red')

    # corr
    corr = np.round(np.corrcoef(actual, predicted)[0,1]**2 , 2)
    last_mse = np.round(hist_obs.history['val_loss'][-1], 2)
    
    # Add labels, gridlines, and colorbar
    plt.xlabel("Actual", fontsize=label_size)
    plt.ylabel("Predicted", fontsize=label_size)
    plt.title("r^2 = " + str(corr) + ", Error = " + str(last_mse))
    plt.grid(True)
    plt.colorbar()

    # Save and show figure
    path = "../figures/"
    plt.savefig(f"{path}eval_act_pred_{name}.png", dpi=200, transparent=True,  bbox_inches='tight')
    plt.show()


plot_loss(hist, 'model_01')
plot_act_pred(model, hist, 'model_01')
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ##### The plot shows a steep decline in both loss values, but no real improvement in the validation loss beyond epoch 20. It's quite likely that this model has overfit - become too tuned to the training data to allow prediction. There are a variety of ways we can avoid this, but a simple one is to slow the rate at which the model learns. We'll refit the model, but will add a `learning_rate` parameter to the compilation step.
#
# ##### Additionally, `callbacks` can be added to the fitting process, in which the fit algorithm will monitor the validation loss. Here, when the validation loss does not improve after 5 epochs, the model stops training.

# %%
model = create_model()

model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

epochs = 100
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  callbacks=[callback],                   # patience
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.9280 - mean_absolute_error: 0.9828 - val_loss: 0.5133 - val_mean_absolute_error: 0.3703
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7675 - mean_absolute_error: 0.5975 - val_loss: 0.5020 - val_mean_absolute_error: 0.3587
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5904 - mean_absolute_error: 0.4846 - val_loss: 0.4962 - val_mean_absolute_error: 0.3549
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5191 - mean_absolute_error: 0.4271 - val_loss: 0.4868 - val_mean_absolute_error: 0.3525
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5219 - mean_absolute_error: 0.4012 - val_loss: 0.4771 - val_mean_absolute_error: 0.3499
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4870 - mean_absolute_error: 0.3846 - val_loss: 0.4617 - val_mean_absolute_error: 0.3476
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4752 - mean_absolute_error: 0.3722 - val_loss: 0.4471 - val_mean_absolute_error: 0.3457
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4367 - mean_absolute_error: 0.3572 - val_loss: 0.4334 - val_mean_absolute_error: 0.3432
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4439 - mean_absolute_error: 0.3578 - val_loss: 0.4255 - val_mean_absolute_error: 0.3396
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4060 - mean_absolute_error: 0.3456 - val_loss: 0.4168 - val_mean_absolute_error: 0.3371
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4069 - mean_absolute_error: 0.3403 - val_loss: 0.4087 - val_mean_absolute_error: 0.3341
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4036 - mean_absolute_error: 0.3358 - val_loss: 0.4052 - val_mean_absolute_error: 0.3324
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4040 - mean_absolute_error: 0.3431 - val_loss: 0.4022 - val_mean_absolute_error: 0.3309
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3980 - mean_absolute_error: 0.3373 - val_loss: 0.3988 - val_mean_absolute_error: 0.3317
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3934 - mean_absolute_error: 0.3379 - val_loss: 0.3955 - val_mean_absolute_error: 0.3300
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4267 - mean_absolute_error: 0.3516 - val_loss: 0.3945 - val_mean_absolute_error: 0.3288
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3963 - mean_absolute_error: 0.3381 - val_loss: 0.3932 - val_mean_absolute_error: 0.3287
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3788 - mean_absolute_error: 0.3307 - val_loss: 0.3911 - val_mean_absolute_error: 0.3294
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3741 - mean_absolute_error: 0.3275 - val_loss: 0.3889 - val_mean_absolute_error: 0.3287
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3645 - mean_absolute_error: 0.3234 - val_loss: 0.3887 - val_mean_absolute_error: 0.3274
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3695 - mean_absolute_error: 0.3253 - val_loss: 0.3858 - val_mean_absolute_error: 0.3267
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3787 - mean_absolute_error: 0.3274 - val_loss: 0.3854 - val_mean_absolute_error: 0.3249
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4066 - mean_absolute_error: 0.3390 - val_loss: 0.3827 - val_mean_absolute_error: 0.3249
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3893 - mean_absolute_error: 0.3364 - val_loss: 0.3820 - val_mean_absolute_error: 0.3248
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3660 - mean_absolute_error: 0.3210 - val_loss: 0.3806 - val_mean_absolute_error: 0.3243
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3577 - mean_absolute_error: 0.3221 - val_loss: 0.3786 - val_mean_absolute_error: 0.3236
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3742 - mean_absolute_error: 0.3259 - val_loss: 0.3784 - val_mean_absolute_error: 0.3240
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3524 - mean_absolute_error: 0.3199 - val_loss: 0.3780 - val_mean_absolute_error: 0.3244
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3385 - mean_absolute_error: 0.3110 - val_loss: 0.3793 - val_mean_absolute_error: 0.3237
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3445 - mean_absolute_error: 0.3151 - val_loss: 0.3781 - val_mean_absolute_error: 0.3236
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3516 - mean_absolute_error: 0.3182 - val_loss: 0.3775 - val_mean_absolute_error: 0.3248
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3593 - mean_absolute_error: 0.3255 - val_loss: 0.3780 - val_mean_absolute_error: 0.3241
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3566 - mean_absolute_error: 0.3207 - val_loss: 0.3767 - val_mean_absolute_error: 0.3247
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3766 - mean_absolute_error: 0.3295 - val_loss: 0.3746 - val_mean_absolute_error: 0.3234
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3383 - mean_absolute_error: 0.3141 - val_loss: 0.3744 - val_mean_absolute_error: 0.3242
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3642 - mean_absolute_error: 0.3265 - val_loss: 0.3729 - val_mean_absolute_error: 0.3238
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3481 - mean_absolute_error: 0.3166 - val_loss: 0.3727 - val_mean_absolute_error: 0.3221
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3537 - mean_absolute_error: 0.3176 - val_loss: 0.3730 - val_mean_absolute_error: 0.3219
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3587 - mean_absolute_error: 0.3217 - val_loss: 0.3719 - val_mean_absolute_error: 0.3223
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3396 - mean_absolute_error: 0.3165 - val_loss: 0.3715 - val_mean_absolute_error: 0.3234
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3392 - mean_absolute_error: 0.3164 - val_loss: 0.3707 - val_mean_absolute_error: 0.3237
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3367 - mean_absolute_error: 0.3173 - val_loss: 0.3702 - val_mean_absolute_error: 0.3233
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3526 - mean_absolute_error: 0.3191 - val_loss: 0.3714 - val_mean_absolute_error: 0.3234
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3673 - mean_absolute_error: 0.3281 - val_loss: 0.3698 - val_mean_absolute_error: 0.3220
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3379 - mean_absolute_error: 0.3124 - val_loss: 0.3675 - val_mean_absolute_error: 0.3216
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3420 - mean_absolute_error: 0.3141 - val_loss: 0.3666 - val_mean_absolute_error: 0.3212
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3459 - mean_absolute_error: 0.3205 - val_loss: 0.3663 - val_mean_absolute_error: 0.3205
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3404 - mean_absolute_error: 0.3143 - val_loss: 0.3656 - val_mean_absolute_error: 0.3220
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3651 - mean_absolute_error: 0.3243 - val_loss: 0.3664 - val_mean_absolute_error: 0.3205
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3296 - mean_absolute_error: 0.3111 - val_loss: 0.3655 - val_mean_absolute_error: 0.3206
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3557 - mean_absolute_error: 0.3207 - val_loss: 0.3651 - val_mean_absolute_error: 0.3214
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3424 - mean_absolute_error: 0.3147 - val_loss: 0.3638 - val_mean_absolute_error: 0.3214
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3502 - mean_absolute_error: 0.3219 - val_loss: 0.3636 - val_mean_absolute_error: 0.3198
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3433 - mean_absolute_error: 0.3166 - val_loss: 0.3652 - val_mean_absolute_error: 0.3197
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3294 - mean_absolute_error: 0.3096 - val_loss: 0.3649 - val_mean_absolute_error: 0.3199
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3488 - mean_absolute_error: 0.3138 - val_loss: 0.3658 - val_mean_absolute_error: 0.3198
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3287 - mean_absolute_error: 0.3085 - val_loss: 0.3652 - val_mean_absolute_error: 0.3201
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3630 - mean_absolute_error: 0.3249 - val_loss: 0.3664 - val_mean_absolute_error: 0.3200

# %%
plot_loss(hist, 'model_02_adjust_lr')
plot_act_pred(model, hist, 'model_02_adjust_lr')
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ##### The plot now shows a good evolution of the loss value.

# %% [markdown]
# ## How does changing the stucture affect the training outcome?
#
# ##### Along with the loss function, the structure of the CNN can be changed. I suggest seeing what happens when you do the following changes individually:
# 1. `Change the Dense layers to have units=10`
# 2. `Uncomment the additional MaxPooling2D and Conv2D layers`
# 3. `Change the loss function to mean_absolute_error`
# 4. `Set Dropout to zero`
#
# ##### Pay mind to how changing these parameters affect the number of parameters to train, how long training time becomes, and the 2D histogram of actual versus predicted OPGs. Feel free to try your own edits to inspect how it affects the testing outcome.

# %%
model = Sequential([  
    InputLayer(shape=(latitude, longitude, channels)),
    Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'),
    # MaxPooling2D(pool_size = (2,2)),                                                    #2 <-- Comment in this line
    # Conv2D(filters = 64, kernel_size = (3,3), padding = 'same', activation = 'relu'),   #2 <-- Comment in this line
    BatchNormalization(),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(0.25),                         #4 <-- Change the dropout from 0.25 to 0.0
    Flatten(),
    Dense(units = 100, activation = 'relu'),  #1 <-- Change the units of the Dense Layers from 100 to 10
    Dense(units = 100, activation = 'relu'),  #1 <-- Change the units of the Dense Layers from 100 to 10
    Dropout(0.25),                         #4 <-- Change the dropout from 0.25 to 0.0
    Dense(units = len(facet_list), activation = 'linear') ])

model.summary()

model.compile(loss = 'mean_squared_error',          #3 <-- Change Loss Function Here from mean_squared_error to mean_absolute_error
              metrics = ["mean_absolute_error", "mean_squared_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

epochs = 80

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

hist = model.fit(train_atmos, train_opg, 
                  batch_size = batch_size,
                  epochs = epochs,                      
                  validation_data = (val_atmos, val_opg),
                  callbacks=[callback],
                  verbose = 1)                     # <-- If you want to silence training, set to 0, if you want to watch it train, set to 1

plot_loss(hist, 'model_03_change_architecture')
plot_act_pred(model, hist, 'model_03_change_architecture')
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_38 (Conv2D)              │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_38 (MaxPooling2D) │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_21 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4645 - mean_absolute_error: 0.8547 - mean_squared_error: 1.4647 - val_loss: 0.5106 - val_mean_absolute_error: 0.3694 - val_mean_squared_error: 0.5054
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7204 - mean_absolute_error: 0.5696 - mean_squared_error: 0.7201 - val_loss: 0.4990 - val_mean_absolute_error: 0.3638 - val_mean_squared_error: 0.4939
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5520 - mean_absolute_error: 0.4799 - mean_squared_error: 0.5519 - val_loss: 0.4847 - val_mean_absolute_error: 0.3607 - val_mean_squared_error: 0.4796
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5341 - mean_absolute_error: 0.4485 - mean_squared_error: 0.5340 - val_loss: 0.4639 - val_mean_absolute_error: 0.3569 - val_mean_squared_error: 0.4590
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5056 - mean_absolute_error: 0.4268 - mean_squared_error: 0.5054 - val_loss: 0.4443 - val_mean_absolute_error: 0.3525 - val_mean_squared_error: 0.4394
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4735 - mean_absolute_error: 0.4036 - mean_squared_error: 0.4736 - val_loss: 0.4255 - val_mean_absolute_error: 0.3504 - val_mean_squared_error: 0.4212
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4586 - mean_absolute_error: 0.3964 - mean_squared_error: 0.4585 - val_loss: 0.4132 - val_mean_absolute_error: 0.3460 - val_mean_squared_error: 0.4091
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4625 - mean_absolute_error: 0.3895 - mean_squared_error: 0.4626 - val_loss: 0.4082 - val_mean_absolute_error: 0.3416 - val_mean_squared_error: 0.4040
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4151 - mean_absolute_error: 0.3713 - mean_squared_error: 0.4152 - val_loss: 0.4013 - val_mean_absolute_error: 0.3380 - val_mean_squared_error: 0.3971
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4123 - mean_absolute_error: 0.3641 - mean_squared_error: 0.4121 - val_loss: 0.3949 - val_mean_absolute_error: 0.3381 - val_mean_squared_error: 0.3912
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3945 - mean_absolute_error: 0.3579 - mean_squared_error: 0.3945 - val_loss: 0.3913 - val_mean_absolute_error: 0.3334 - val_mean_squared_error: 0.3880
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3925 - mean_absolute_error: 0.3513 - mean_squared_error: 0.3926 - val_loss: 0.3867 - val_mean_absolute_error: 0.3309 - val_mean_squared_error: 0.3835
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4093 - mean_absolute_error: 0.3557 - mean_squared_error: 0.4093 - val_loss: 0.3841 - val_mean_absolute_error: 0.3298 - val_mean_squared_error: 0.3809
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3876 - mean_absolute_error: 0.3453 - mean_squared_error: 0.3877 - val_loss: 0.3832 - val_mean_absolute_error: 0.3303 - val_mean_squared_error: 0.3798
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3829 - mean_absolute_error: 0.3444 - mean_squared_error: 0.3830 - val_loss: 0.3808 - val_mean_absolute_error: 0.3272 - val_mean_squared_error: 0.3778
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3596 - mean_absolute_error: 0.3366 - mean_squared_error: 0.3596 - val_loss: 0.3786 - val_mean_absolute_error: 0.3274 - val_mean_squared_error: 0.3756
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3759 - mean_absolute_error: 0.3404 - mean_squared_error: 0.3759 - val_loss: 0.3773 - val_mean_absolute_error: 0.3244 - val_mean_squared_error: 0.3745
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3834 - mean_absolute_error: 0.3421 - mean_squared_error: 0.3835 - val_loss: 0.3730 - val_mean_absolute_error: 0.3240 - val_mean_squared_error: 0.3704
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3592 - mean_absolute_error: 0.3328 - mean_squared_error: 0.3591 - val_loss: 0.3706 - val_mean_absolute_error: 0.3240 - val_mean_squared_error: 0.3680
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3853 - mean_absolute_error: 0.3444 - mean_squared_error: 0.3852 - val_loss: 0.3706 - val_mean_absolute_error: 0.3240 - val_mean_squared_error: 0.3679
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3701 - mean_absolute_error: 0.3377 - mean_squared_error: 0.3699 - val_loss: 0.3669 - val_mean_absolute_error: 0.3221 - val_mean_squared_error: 0.3644
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3786 - mean_absolute_error: 0.3354 - mean_squared_error: 0.3786 - val_loss: 0.3712 - val_mean_absolute_error: 0.3213 - val_mean_squared_error: 0.3690
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3447 - mean_absolute_error: 0.3258 - mean_squared_error: 0.3446 - val_loss: 0.3655 - val_mean_absolute_error: 0.3241 - val_mean_squared_error: 0.3630
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3453 - mean_absolute_error: 0.3245 - mean_squared_error: 0.3454 - val_loss: 0.3649 - val_mean_absolute_error: 0.3221 - val_mean_squared_error: 0.3625
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3464 - mean_absolute_error: 0.3260 - mean_squared_error: 0.3465 - val_loss: 0.3660 - val_mean_absolute_error: 0.3213 - val_mean_squared_error: 0.3635
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3528 - mean_absolute_error: 0.3308 - mean_squared_error: 0.3527 - val_loss: 0.3632 - val_mean_absolute_error: 0.3224 - val_mean_squared_error: 0.3605
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3658 - mean_absolute_error: 0.3343 - mean_squared_error: 0.3659 - val_loss: 0.3622 - val_mean_absolute_error: 0.3211 - val_mean_squared_error: 0.3599
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3372 - mean_absolute_error: 0.3233 - mean_squared_error: 0.3373 - val_loss: 0.3601 - val_mean_absolute_error: 0.3200 - val_mean_squared_error: 0.3576
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3667 - mean_absolute_error: 0.3323 - mean_squared_error: 0.3667 - val_loss: 0.3654 - val_mean_absolute_error: 0.3198 - val_mean_squared_error: 0.3627
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3370 - mean_absolute_error: 0.3220 - mean_squared_error: 0.3371 - val_loss: 0.3607 - val_mean_absolute_error: 0.3195 - val_mean_squared_error: 0.3584
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3425 - mean_absolute_error: 0.3238 - mean_squared_error: 0.3425 - val_loss: 0.3623 - val_mean_absolute_error: 0.3183 - val_mean_squared_error: 0.3599
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2962 - mean_absolute_error: 0.3010 - mean_squared_error: 0.2963 - val_loss: 0.3607 - val_mean_absolute_error: 0.3184 - val_mean_squared_error: 0.3585
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3469 - mean_absolute_error: 0.3226 - mean_squared_error: 0.3470 - val_loss: 0.3569 - val_mean_absolute_error: 0.3172 - val_mean_squared_error: 0.3546
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3451 - mean_absolute_error: 0.3219 - mean_squared_error: 0.3449 - val_loss: 0.3593 - val_mean_absolute_error: 0.3184 - val_mean_squared_error: 0.3568
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3340 - mean_absolute_error: 0.3189 - mean_squared_error: 0.3341 - val_loss: 0.3595 - val_mean_absolute_error: 0.3170 - val_mean_squared_error: 0.3575
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3340 - mean_absolute_error: 0.3197 - mean_squared_error: 0.3340 - val_loss: 0.3579 - val_mean_absolute_error: 0.3182 - val_mean_squared_error: 0.3555
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3342 - mean_absolute_error: 0.3193 - mean_squared_error: 0.3342 - val_loss: 0.3615 - val_mean_absolute_error: 0.3172 - val_mean_squared_error: 0.3592
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3367 - mean_absolute_error: 0.3206 - mean_squared_error: 0.3366 - val_loss: 0.3612 - val_mean_absolute_error: 0.3174 - val_mean_squared_error: 0.3590
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# #### Notice the differences between outputs when changing the hyperparameters:
# 1. `Change the Dense layers to have units=10`:
#   The number of trainable parameters decreases considerably from 95,678 to 13,714. Though the mean squared error reaches a minimum around 80 epochs, the OPG heatmap indicates a decrease in r^2 and an increase in error. Overall, the model is less able to predict more extreme OPGs. Possibiliy from too little parameters? Possibly the patience is too sensitive and it should train for longer?
#
# 2. `Uncomment the additional MaxPooling2D and Conv2D layers`:
#   Additional MaxPooling2D and Conv2D layers decreased the number of trainable parameters from 95,614 to 75,774. Based on the mean squared error, the model seems to reach a minimum in error somewhere around 60 epochs. The addition of MaxPooling2D and Conv2D layers did not significantly improve or worsen the OPG predictions. More layers don't always improve the model?
#
# 3. `Change the loss function to mean_absolute_error`:
#   The number of trainable parameters are consistent. Based on the plot of mean absolute error by epoch, the model tends to train very quickly in the beginning and trains slowly until ending. The OPG heatmap shows OPGs are more underpredicted than when using mean_squared_error, most likely due to the loss function. Mean squared error, since it is squared, forces the model to focus more on larger loss values.
#
# 4. `Set Dropout to zero`:
#    The number of trainable parameters are consistent. Based on the plot of mean squared error by epoch, the model tends to train very quickly, possibly ending before epoch 20. This can cause the model to overfitting to the training data.
#
#
# #### What you choose for hyperparameters and structure all depends on what your goals are.
