# %% [markdown]
# # CIROH Developers Conference: Hydrological Applications of ML
# ### CNNs for Predicting Daily Orographic Precipitation Gradients (OPGs) for Atmospheric Downscaling

# %% [markdown]
# ## Introduction
#
# In this exercise, we'll build a convolutional neural network (CNN) for regression of orographic precipitation gradients of Northern Utah. Other uses include:
#
# - Image classification
# - Image denoising or reconstruction
#
# But all methods are based around two basic operations:
#
# - Convolution: in this step, the network learns a series of kernels or filters that transform the original image in some way. These are similar to filters that are used in standard image processing (e.g. low-pass filters), but filters are chosen by how well the transformed image maps to the outcome variable. To put this another way, these filters identify shapes or features that are important in differentiating between different outcomes
# - Max-pooling: in this step, the image resolution is transformed. In general, the resolution is halved, by aggregating groups of four pixels in a two by two window.
#
# In general, these steps are repeated several times. As this progresses, the small shapes identified in the first set of convolutions are progressively combined into larger structures. For example, a series of small curves or lines could be aggregated into a cat's eye.

# %% [markdown]
# ## Data processing
# ##### Let's start, as usual, by loading the libraries we'll need for the lab:

# %%
# Data manipulation
import pandas as pd
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt
from matplotlib import colors
import nclcmaps as ncm

# %% [markdown]
# ##### Now we set the path to the data folders and download the datasets. If you have any questions about setting this path, please ask.

# %%
# load in the atmospheric data
path      = "../datasets/era5_atmos/"
IVT       = xr.open_dataset(f"{path}IVT_sfc.nc")
precip    = xr.open_dataset(f"{path}precip_sfc.nc")*1000
temp700   = xr.open_dataset(f"{path}temp_700.nc")-273.15
uwinds700 = xr.open_dataset(f"{path}uwnd_700.nc")
vwinds700 = xr.open_dataset(f"{path}vwnd_700.nc")
hgt500    = xr.open_dataset(f"{path}hgt_500.nc")/9.81

# load in the OPGs
path = "../datasets/facets_and_opgs/"
opg  = pd.read_csv(f"{path}winter_northernUT_opg.csv", index_col=0)
facet_list = opg.columns.values
opg = opg.values

# %% [markdown]
# #### Standardizing the Datasets:
#
# ##### Since the values between the atmospheric variables contain a large variability in scale, we standardize each variable individually. This levels the playing field, so to speak, so that all atmospheric variables are taken into account within the CNN. This also applies to the facet OPGs, as a machine learning model is better equipted predicting values between -1 and 1.
#
# ##### In other cases, you may prefer to normalize the datasets.

# %%
IVT       = (IVT - IVT.mean(dim="time")) / IVT.std(dim="time")
precip    = (precip - precip.mean(dim="time")) / precip.std(dim="time")
temp700   = (temp700 - temp700.mean(dim="time")) / temp700.std(dim="time")
uwinds700 = (uwinds700 - uwinds700.mean(dim="time")) / uwinds700.std(dim="time")
vwinds700 = (vwinds700 - vwinds700.mean(dim="time")) / vwinds700.std(dim="time")
hgt500    = (hgt500 - hgt500.mean(dim="time")) / hgt500.std(dim="time")

opg_mean = np.nanmean(opg, axis=0) # Save OPG mean and standard deviation so that we can
opg_std  = np.nanstd(opg, axis=0)  # convert back to true values from standardized values later on.
opg = (opg - opg_mean) / opg_std

# %% [markdown]
# ##### Unique to the OPG dataset, for days without precipitation, the value within the array are NaNs. However, machine learning algoirthms of this architecture are unable to predict NaN as an output. Therefore, days without observations are set to zero, as it is the average value of the dataset.
#
# ##### In classification tasks, the missing values are often set to a new catagory.

# %%
opg[np.isnan(opg)] = 0

# %% [markdown]
# ##### To input the atmospheric data into the CNN model, the atmospheric variables are combined into one array.

# %%
# Combine the atmospheric data into one array
atmos = np.concatenate((IVT.IVT.values[...,np.newaxis], 
                        precip.precip.values[...,np.newaxis],
                        temp700.temp.values[...,np.newaxis],
                        uwinds700.uwnd.values[...,np.newaxis],
                        vwinds700.vwnd.values[...,np.newaxis],
                        hgt500.hgt.values[...,np.newaxis]), axis=3)
print(np.shape(atmos))
# Out:
# (2708, 19, 27, 6)

# %% [markdown]
# ##### The above output lists the dimensions of all the atmospheric variables combined. It contains 2708 observation days or 'images', with a 19 x 27 grid of latitudes and longitudes. Each atmospheric variable represents a channel, here we have 6 channels.
#
# ##### Channels can be viewed as layers of the image. For example, when using visual images of RGB colors, there would be 3 channels.
#
# ##### CNNs are not limited only to images of shape `(samples, height, width, channels)`, CNNs can be used to evaluate vector data `(samples, features)`, timeseries data `(samples, timesteps, features)`, and video data `(samples, frames, height, width, channels)`.

# %%
latitude  = 19 # height
longitude = 27 # width
channels  = 6  # channel

# %% [markdown]
# ##### When creating a ML model, the datasets are split into training, validation, and testing subsets. The model is trained on the training subset, evaluated on the validation subset, and tested on the testing subset.
#
# ##### These datasets are often randomly shuffled to produce training, validation, and testing subsets. If redundency exists in your dataset, or in our case, multipday precipitation events, it can be important to split the datasets differently. Such as by week, months, or years.
#
# ##### The split of these datasets are user defined, here we'll use a 70/15/15% split.

# %%
np.random.seed(42)
rand_ind = np.random.permutation(np.arange(np.shape(atmos)[0]))

train_atmos = atmos[rand_ind[:1896], ...]
test_atmos  = atmos[rand_ind[1896:2302], ...]
val_atmos   = atmos[rand_ind[2302:], ...]

train_opg = opg[rand_ind[:1896], ...]
test_opg  = opg[rand_ind[1896:2302], ...]
val_opg   = opg[rand_ind[2302:], ...]

print(np.shape(test_atmos))
# Out:
# (406, 19, 27, 6)

# %% [markdown]
# ##### The last parameter we'll set here is the batch size. This parameter controls how many samples are processed in training simultaneously, typically between 8 and 128. The dataset is separated into batches, processed by the model, and the weights within the model are adjusted|. Once all batches are processed, one epoch has been processed.
#
# ##### This also controls how much memory is used per step of training, which is very useful if you're training on a computer with limited memory.

# %%
batch_size = 32

# %% [markdown]
# ## Create CNN Model
#
# ##### Let's now set up the model. As this is quite a complex model, we'll do this as a series of steps rather than in one go. First, import all the modules from Keras that we'll need:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (InputLayer, 
                                      Conv2D,
                                      Dense,
                                      ReLU,LeakyReLU,
                                      BatchNormalization, 
                                      MaxPooling2D, 
                                      Dropout,
                                      Flatten)
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Now, create a template sequential model, this way we can build the model incrementally:

# %%
model = Sequential()

# %% [markdown]
# ##### First, we'll use `InputLayer` to declare the shape of the input data. Notice that we care about the entire input set, not the batch size.

# %%
model.add(InputLayer(shape=(latitude, longitude, channels)))

# %% [markdown]
# ##### Next we add the first hidden layer, `Conv2D`. This is a convolutional layer, where we'll create 16 filters (or convolutions) based on the original images, with a 3x3 kernel. We'll add padding to the input of the `Conv2D` layer, this adds the appropriate number of rows and columns around the input image so that the output image is the `same` height and width.

# %%
model.add(Conv2D(filters = 16, kernel_size = (3,3), padding = 'same'))

# %% [markdown]
# ##### We'll then take the output of this layer and pass it through a `ReLU()` activation function (this could have been included directly in the convolutional layer, but this allows a little more control on the process):

# %%
model.add(ReLU())

# %% [markdown]
# ##### Now, we add a `MaxPooling2D` layer. As a reminder, this reduces the resolution of the output from the previous layer by a simple filter, forcing the next layer of the network to focus on larger image features. We'll also add a `Dropout` layer. This is a form of regularization. It randomly sets some connection weights to 0 (i.e. having no contribution to the model), which can reduce overfitting.

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Let's add another convolutional layer, this time with 32 filters, and pass this through a ReLU activation function.

# %%
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'same'))
model.add(ReLU())

# %% [markdown]
# ##### We'll take the output of this function and normalize the weights. This is a simple method that adjusts the mean weight to close to zero and reduces the amount of variation. This helps avoid gradient problems with very small or very large weights

# %%
model.add(BatchNormalization())

# %% [markdown]
# ##### And we'll run the output of this through a max-pooling function with dropout:

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Now we'll add layers to connect the output of this last `MaxPooling2D` step to the output (the OPGs). The first thing we need to do is to `Flatten()` the output. The output of the max-pooling is a tensor of shape (4, 6, 32). The size of 4x5 is a result of the two max-pooling operations and the 32 is the number of filters from the second convolution. The `Flatten()` function will flatten this into a rank 1 tensor of shape (768).

# %%
model.add(Flatten())

# %% [markdown]
# ##### Next we'll pass this flattened layer through a `Dense()` layer, which are densely conncted neural layers. And then through `ReLU()` activation and a dropout

# %%
model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dropout(.25))

# %% [markdown]
# ##### Finally, we need to output predictions. As this is a regression task, the final layer needs to have the same number of nodes as northern Utah facets, and the output is passed through a linear activation function. Linear activation functions are typically used whe you're trying to predict continuous values.

# %%
model.add(Dense(units = len(facet_list), activation = 'linear'))

# %% [markdown]
# ##### More practically, we'll create a function that will build the model in one go. This will allow us to easily create new versions for testing.

# %%
def create_model():
    model = Sequential([  
        InputLayer(shape=(latitude, longitude, channels)),
        Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu', name='Convolution_01'),
        MaxPooling2D(pool_size = (2,2), name='Max_Pooling_01'),
        Dropout(.25),
        Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu', name='Convolution_02'),
        BatchNormalization(name='Batch_Normalization'),
        MaxPooling2D(pool_size = (2,2), name='Max_Pooling_02'),
        Dropout(.25),
        Flatten(),
        Dense(units = 100, activation = 'relu', name='Hidden_Layer_01'),
        Dense(units = 100, activation = 'relu', name='Hidden_Layer_02'),
        Dropout(.25),
        Dense(units = len(facet_list), activation = 'linear', name='Output')
    ])
    return model

# %% [markdown]
# ##### Let's take a look at the whole thing:

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Convolution_01 (Conv2D)         │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Max_Pooling_01 (MaxPooling2D)   │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Convolution_02 (Conv2D)         │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Batch_Normalization             │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Max_Pooling_02 (MaxPooling2D)   │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_01 (Dense)         │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_02 (Dense)         │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)

# %% [markdown]
# ##### Our model has a little over 95,000 parameters or weights to train (hence the need for a lot of images). Note that there are small set of non-trainable parameter from the normalization layer.
#
# ##### We can also generate a simple visualization:

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True,dpi=75)

# %% [markdown]
# ##### The next step is to compile the model. This is an optimization function, a loss function and performance metric. A good option for the loss function in a regression problem is `mean_squared_error`, metrics allows the user to add aditional functions to monitor training. The optimizer implements the agorithmn which updates the weights of the model.

# %%
model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop())

# %% [markdown]
# ## Training the model
#
# ##### We'll now train the model for 50 epochs using the `fit()` method upon our built model. We specify:
#
# - `train_atmos`: The training subset of the atmospheric variables
# - `train_opg`: The training subset of the observed OPGs
# - `batch_size`: The number of samples or observation days used per gradient update.
# - `epochs`: The number of full training iterations.
# - `validation_data`: The validation subset of the atmospheric variables and observed OPGs
#
# ##### This takes a few minutes to train (on my laptop). It's worth remembering what is going on here: the algorithm is reading in batches of 32 images, rescaling them, updating model weights through back propagation and then repeating the whole thing 50 times. As we previously defined a separate validation subset, this routine will calculate two losses:
# - The training loss. This is how accurately the model can predict OPG from the atmospheric 'images' that are being used to update the weights
# - The validation loss. This is how accurately the model can predict OPG from a set of atmospheric 'images' that are not used in updating the weights
#
# ##### As the model continues to train, you should see the loss decrease for both of these, but will likely stabilize at a certain point.

# %%
epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8876 - mean_absolute_error: 0.5921 - val_loss: 0.4759 - val_mean_absolute_error: 0.3369
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4444 - mean_absolute_error: 0.3675 - val_loss: 0.4331 - val_mean_absolute_error: 0.3291
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3783 - mean_absolute_error: 0.3325 - val_loss: 0.4006 - val_mean_absolute_error: 0.3180
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3666 - mean_absolute_error: 0.3287 - val_loss: 0.3869 - val_mean_absolute_error: 0.3204
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3638 - mean_absolute_error: 0.3243 - val_loss: 0.3682 - val_mean_absolute_error: 0.3154
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3665 - mean_absolute_error: 0.3221 - val_loss: 0.3908 - val_mean_absolute_error: 0.3277
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3631 - mean_absolute_error: 0.3236 - val_loss: 0.3680 - val_mean_absolute_error: 0.3123
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3421 - mean_absolute_error: 0.3144 - val_loss: 0.3725 - val_mean_absolute_error: 0.3167
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3446 - mean_absolute_error: 0.3161 - val_loss: 0.3621 - val_mean_absolute_error: 0.3179
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3196 - mean_absolute_error: 0.3041 - val_loss: 0.3579 - val_mean_absolute_error: 0.3180
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3222 - mean_absolute_error: 0.3034 - val_loss: 0.3508 - val_mean_absolute_error: 0.3144
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3402 - mean_absolute_error: 0.3130 - val_loss: 0.3676 - val_mean_absolute_error: 0.3178
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3168 - mean_absolute_error: 0.3005 - val_loss: 0.3585 - val_mean_absolute_error: 0.3154
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3378 - mean_absolute_error: 0.3088 - val_loss: 0.3596 - val_mean_absolute_error: 0.3110
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3073 - mean_absolute_error: 0.2996 - val_loss: 0.3540 - val_mean_absolute_error: 0.3181
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3116 - mean_absolute_error: 0.2992 - val_loss: 0.3554 - val_mean_absolute_error: 0.3190
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3075 - mean_absolute_error: 0.2983 - val_loss: 0.3591 - val_mean_absolute_error: 0.3207
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3061 - mean_absolute_error: 0.3024 - val_loss: 0.3480 - val_mean_absolute_error: 0.3116
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3017 - mean_absolute_error: 0.2948 - val_loss: 0.3487 - val_mean_absolute_error: 0.3160
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3144 - mean_absolute_error: 0.3053 - val_loss: 0.3492 - val_mean_absolute_error: 0.3109
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2830 - mean_absolute_error: 0.2865 - val_loss: 0.3501 - val_mean_absolute_error: 0.3176
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2889 - mean_absolute_error: 0.2865 - val_loss: 0.3480 - val_mean_absolute_error: 0.3138
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2997 - mean_absolute_error: 0.2952 - val_loss: 0.3440 - val_mean_absolute_error: 0.3118
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2841 - mean_absolute_error: 0.2889 - val_loss: 0.3455 - val_mean_absolute_error: 0.3139
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2858 - mean_absolute_error: 0.2896 - val_loss: 0.3479 - val_mean_absolute_error: 0.3138
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2890 - mean_absolute_error: 0.2859 - val_loss: 0.3501 - val_mean_absolute_error: 0.3158
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2967 - mean_absolute_error: 0.2931 - val_loss: 0.3473 - val_mean_absolute_error: 0.3122
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2862 - mean_absolute_error: 0.2895 - val_loss: 0.3511 - val_mean_absolute_error: 0.3180
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2762 - mean_absolute_error: 0.2858 - val_loss: 0.3556 - val_mean_absolute_error: 0.3221
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2671 - mean_absolute_error: 0.2838 - val_loss: 0.3623 - val_mean_absolute_error: 0.3173
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2883 - mean_absolute_error: 0.2897 - val_loss: 0.3432 - val_mean_absolute_error: 0.3119
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2686 - mean_absolute_error: 0.2813 - val_loss: 0.3537 - val_mean_absolute_error: 0.3145
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2578 - mean_absolute_error: 0.2788 - val_loss: 0.3525 - val_mean_absolute_error: 0.3157
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2795 - mean_absolute_error: 0.2898 - val_loss: 0.3538 - val_mean_absolute_error: 0.3149
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2656 - mean_absolute_error: 0.2819 - val_loss: 0.3531 - val_mean_absolute_error: 0.3145
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2723 - mean_absolute_error: 0.2833 - val_loss: 0.3521 - val_mean_absolute_error: 0.3178
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2780 - mean_absolute_error: 0.2849 - val_loss: 0.3499 - val_mean_absolute_error: 0.3135
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2685 - mean_absolute_error: 0.2818 - val_loss: 0.3450 - val_mean_absolute_error: 0.3132
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2596 - mean_absolute_error: 0.2801 - val_loss: 0.3573 - val_mean_absolute_error: 0.3171
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2577 - mean_absolute_error: 0.2778 - val_loss: 0.3508 - val_mean_absolute_error: 0.3180
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2538 - mean_absolute_error: 0.2751 - val_loss: 0.3524 - val_mean_absolute_error: 0.3160
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2673 - mean_absolute_error: 0.2825 - val_loss: 0.3545 - val_mean_absolute_error: 0.3201
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2558 - mean_absolute_error: 0.2791 - val_loss: 0.3449 - val_mean_absolute_error: 0.3142
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2659 - mean_absolute_error: 0.2795 - val_loss: 0.3490 - val_mean_absolute_error: 0.3118
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2535 - mean_absolute_error: 0.2749 - val_loss: 0.3530 - val_mean_absolute_error: 0.3157
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2439 - mean_absolute_error: 0.2709 - val_loss: 0.3513 - val_mean_absolute_error: 0.3133
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2514 - mean_absolute_error: 0.2760 - val_loss: 0.3469 - val_mean_absolute_error: 0.3140
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2539 - mean_absolute_error: 0.2792 - val_loss: 0.3527 - val_mean_absolute_error: 0.3144
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2573 - mean_absolute_error: 0.2792 - val_loss: 0.3509 - val_mean_absolute_error: 0.3185
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2516 - mean_absolute_error: 0.2780 - val_loss: 0.3657 - val_mean_absolute_error: 0.3255
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2630 - mean_absolute_error: 0.2807 - val_loss: 0.3567 - val_mean_absolute_error: 0.3147
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2448 - mean_absolute_error: 0.2732 - val_loss: 0.3498 - val_mean_absolute_error: 0.3129
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2453 - mean_absolute_error: 0.2726 - val_loss: 0.3578 - val_mean_absolute_error: 0.3205
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2511 - mean_absolute_error: 0.2760 - val_loss: 0.3573 - val_mean_absolute_error: 0.3201
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2429 - mean_absolute_error: 0.2751 - val_loss: 0.3557 - val_mean_absolute_error: 0.3201
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2476 - mean_absolute_error: 0.2744 - val_loss: 0.3613 - val_mean_absolute_error: 0.3246
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2455 - mean_absolute_error: 0.2756 - val_loss: 0.3663 - val_mean_absolute_error: 0.3192
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2393 - mean_absolute_error: 0.2743 - val_loss: 0.3629 - val_mean_absolute_error: 0.3144
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2373 - mean_absolute_error: 0.2673 - val_loss: 0.3633 - val_mean_absolute_error: 0.3266
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2237 - mean_absolute_error: 0.2618 - val_loss: 0.3674 - val_mean_absolute_error: 0.3251
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2498 - mean_absolute_error: 0.2758 - val_loss: 0.3604 - val_mean_absolute_error: 0.3226
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2353 - mean_absolute_error: 0.2709 - val_loss: 0.3597 - val_mean_absolute_error: 0.3217
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2312 - mean_absolute_error: 0.2675 - val_loss: 0.3569 - val_mean_absolute_error: 0.3180
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2292 - mean_absolute_error: 0.2652 - val_loss: 0.3565 - val_mean_absolute_error: 0.3166
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2369 - mean_absolute_error: 0.2726 - val_loss: 0.3585 - val_mean_absolute_error: 0.3215
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2319 - mean_absolute_error: 0.2658 - val_loss: 0.3624 - val_mean_absolute_error: 0.3228
# Epoch 67/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2279 - mean_absolute_error: 0.2680 - val_loss: 0.3586 - val_mean_absolute_error: 0.3152
# Epoch 68/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2291 - mean_absolute_error: 0.2653 - val_loss: 0.3557 - val_mean_absolute_error: 0.3201
# Epoch 69/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2343 - mean_absolute_error: 0.2719 - val_loss: 0.3550 - val_mean_absolute_error: 0.3154
# Epoch 70/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2399 - mean_absolute_error: 0.2743 - val_loss: 0.3610 - val_mean_absolute_error: 0.3166
# Epoch 71/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2308 - mean_absolute_error: 0.2680 - val_loss: 0.3570 - val_mean_absolute_error: 0.3202
# Epoch 72/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2295 - mean_absolute_error: 0.2682 - val_loss: 0.3556 - val_mean_absolute_error: 0.3158
# Epoch 73/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2297 - mean_absolute_error: 0.2668 - val_loss: 0.3648 - val_mean_absolute_error: 0.3211
# Epoch 74/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2148 - mean_absolute_error: 0.2591 - val_loss: 0.3635 - val_mean_absolute_error: 0.3233
# Epoch 75/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2245 - mean_absolute_error: 0.2633 - val_loss: 0.3668 - val_mean_absolute_error: 0.3355
# Epoch 76/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2355 - mean_absolute_error: 0.2689 - val_loss: 0.3534 - val_mean_absolute_error: 0.3167
# Epoch 77/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2294 - mean_absolute_error: 0.2693 - val_loss: 0.3605 - val_mean_absolute_error: 0.3186
# Epoch 78/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2288 - mean_absolute_error: 0.2698 - val_loss: 0.3691 - val_mean_absolute_error: 0.3221
# Epoch 79/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2183 - mean_absolute_error: 0.2631 - val_loss: 0.3602 - val_mean_absolute_error: 0.3186
# Epoch 80/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2100 - mean_absolute_error: 0.2568 - val_loss: 0.3577 - val_mean_absolute_error: 0.3193

# %% [markdown]
# ##### Now plot the evolution of the loss function and the actual versus predicted OPGs:

# %%
def plot_loss(hist_obs):
    # Define label sizes
    label_size = 14
    tick_size = 12
    
    # Create Figure
    plt.figure(figsize=(7, 4))
    plt.plot(hist_obs.history['loss'], label='train')
    plt.plot(hist_obs.history['val_loss'], label='valid')
    plt.xlabel("Epochs", fontsize=label_size)
    plt.ylabel("Mean Squared Error", fontsize=label_size)
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()

    # Save and show figure
    path = "../figures/"
    plt.savefig(f"{path}eval_loss.png", dpi=200, transparent=True,  bbox_inches='tight')
    plt.show()

def plot_act_pred(modelx, hist_obs):
    # Using our fitted model, predict OPGs from the testing subset.
    predicted = modelx.predict(test_atmos)

    # set zero OPGs to nan
    actual = test_opg
    actual[actual==0] = np.nan
    predicted[predicted==0] = np.nan
    
    # Convert from standardized OPG to mm/m OPG
    actual    = (test_opg * opg_std) + opg_mean
    predicted = (predicted * opg_std) + opg_mean
    
    # Lets reshape our OPGs and remove NaN OPG days
    actual    = np.reshape(actual, -1)
    predicted = np.reshape(predicted, -1)
    idx       = np.isnan(actual) # Identify days with OPG observations
    actual    = actual[idx==False]
    predicted = predicted[idx==False]
    
    # Formulate the x and y axis limits
    max_val = np.max((np.max(predicted[:]), np.max(actual[:])))
    min_val = np.min((np.min(predicted[:]), np.min(actual[:])))
    max_val = 0.05
    min_val = -0.05
    
    # Define plot colormap
    cmap_gnuplot2 = ncm.cmap("MPL_gnuplot2")
    
    # Define label sizes
    label_size = 14
    tick_size = 12
    
    # Create Figure
    plt.figure(figsize=(6, 5))
    
    # Formulate the heatmap variables
    heatmap, xedges, yedges = np.histogram2d(np.reshape(actual, -1), np.reshape(predicted, -1), bins=100,
                                 range=[[min_val, max_val],[min_val, max_val]])
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

    # Plot heatmap
    plt.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap_gnuplot2, norm=colors.LogNorm())

    # Plot One-to-one line
    plt.plot([xedges[0], xedges[-1]], [yedges[0], yedges[-1]], c='red')

    # corr
    corr = np.round(np.corrcoef(actual, predicted)[0,1]**2 , 2)
    last_mse = np.round(hist_obs.history['val_loss'][-1], 2)
    
    # Add labels, gridlines, and colorbar
    plt.xlabel("Actual", fontsize=label_size)
    plt.ylabel("Predicted", fontsize=label_size)
    plt.title("r^2 = " + str(corr) + ", Error = " + str(last_mse))
    plt.grid(True)
    plt.colorbar()


plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ##### The plot shows a steep decline in both loss values, but no real improvement beyond epoch 20. It's quite likely that this model has overfit - become too tuned to the training data to allow prediction. There are a variety of ways we can avoid this, but a simple one is to slow the rate at which the model learns. We'll refit the model, but will add a `learning_rate` parameter to the compilation step.
#
# ##### Additionally, `callbacks` can be added to the fitting process, in which the fit algorithm will monitor the validation loss. Here, when the validation loss does not improve after 5 epochs, the model stops training.

# %%
model = create_model()

model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  callbacks=[callback],                   # patience
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7494 - mean_absolute_error: 0.9564 - val_loss: 0.5153 - val_mean_absolute_error: 0.3692
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7493 - mean_absolute_error: 0.5934 - val_loss: 0.5039 - val_mean_absolute_error: 0.3562
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5700 - mean_absolute_error: 0.4802 - val_loss: 0.4971 - val_mean_absolute_error: 0.3524
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5058 - mean_absolute_error: 0.4191 - val_loss: 0.4899 - val_mean_absolute_error: 0.3522
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4607 - mean_absolute_error: 0.3809 - val_loss: 0.4801 - val_mean_absolute_error: 0.3539
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5221 - mean_absolute_error: 0.3915 - val_loss: 0.4709 - val_mean_absolute_error: 0.3556
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4831 - mean_absolute_error: 0.3773 - val_loss: 0.4636 - val_mean_absolute_error: 0.3520
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4297 - mean_absolute_error: 0.3506 - val_loss: 0.4528 - val_mean_absolute_error: 0.3528
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4210 - mean_absolute_error: 0.3479 - val_loss: 0.4457 - val_mean_absolute_error: 0.3497
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4236 - mean_absolute_error: 0.3481 - val_loss: 0.4397 - val_mean_absolute_error: 0.3484
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4373 - mean_absolute_error: 0.3542 - val_loss: 0.4341 - val_mean_absolute_error: 0.3477
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4341 - mean_absolute_error: 0.3535 - val_loss: 0.4275 - val_mean_absolute_error: 0.3441
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4271 - mean_absolute_error: 0.3478 - val_loss: 0.4238 - val_mean_absolute_error: 0.3417
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4029 - mean_absolute_error: 0.3405 - val_loss: 0.4223 - val_mean_absolute_error: 0.3434
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4014 - mean_absolute_error: 0.3408 - val_loss: 0.4163 - val_mean_absolute_error: 0.3404
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3836 - mean_absolute_error: 0.3352 - val_loss: 0.4183 - val_mean_absolute_error: 0.3441
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3710 - mean_absolute_error: 0.3256 - val_loss: 0.4127 - val_mean_absolute_error: 0.3400
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3919 - mean_absolute_error: 0.3357 - val_loss: 0.4116 - val_mean_absolute_error: 0.3422
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3979 - mean_absolute_error: 0.3395 - val_loss: 0.4052 - val_mean_absolute_error: 0.3388
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3579 - mean_absolute_error: 0.3224 - val_loss: 0.4073 - val_mean_absolute_error: 0.3395
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3752 - mean_absolute_error: 0.3286 - val_loss: 0.4056 - val_mean_absolute_error: 0.3393
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3719 - mean_absolute_error: 0.3263 - val_loss: 0.4034 - val_mean_absolute_error: 0.3383
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3779 - mean_absolute_error: 0.3295 - val_loss: 0.4073 - val_mean_absolute_error: 0.3420
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3830 - mean_absolute_error: 0.3346 - val_loss: 0.4023 - val_mean_absolute_error: 0.3384
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3440 - mean_absolute_error: 0.3155 - val_loss: 0.4045 - val_mean_absolute_error: 0.3428
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3598 - mean_absolute_error: 0.3239 - val_loss: 0.3967 - val_mean_absolute_error: 0.3366
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3519 - mean_absolute_error: 0.3194 - val_loss: 0.3963 - val_mean_absolute_error: 0.3378
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3512 - mean_absolute_error: 0.3224 - val_loss: 0.3983 - val_mean_absolute_error: 0.3407
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3845 - mean_absolute_error: 0.3319 - val_loss: 0.3915 - val_mean_absolute_error: 0.3356
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4052 - mean_absolute_error: 0.3404 - val_loss: 0.3915 - val_mean_absolute_error: 0.3383
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3586 - mean_absolute_error: 0.3235 - val_loss: 0.3956 - val_mean_absolute_error: 0.3389
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3677 - mean_absolute_error: 0.3283 - val_loss: 0.3919 - val_mean_absolute_error: 0.3381
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3667 - mean_absolute_error: 0.3241 - val_loss: 0.3885 - val_mean_absolute_error: 0.3357
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3726 - mean_absolute_error: 0.3313 - val_loss: 0.3927 - val_mean_absolute_error: 0.3386
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3567 - mean_absolute_error: 0.3235 - val_loss: 0.3925 - val_mean_absolute_error: 0.3381
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3504 - mean_absolute_error: 0.3216 - val_loss: 0.3868 - val_mean_absolute_error: 0.3351
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3345 - mean_absolute_error: 0.3121 - val_loss: 0.3879 - val_mean_absolute_error: 0.3369
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3485 - mean_absolute_error: 0.3213 - val_loss: 0.3909 - val_mean_absolute_error: 0.3394
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3598 - mean_absolute_error: 0.3238 - val_loss: 0.3837 - val_mean_absolute_error: 0.3339
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3511 - mean_absolute_error: 0.3218 - val_loss: 0.3803 - val_mean_absolute_error: 0.3301
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3521 - mean_absolute_error: 0.3227 - val_loss: 0.3839 - val_mean_absolute_error: 0.3341
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3479 - mean_absolute_error: 0.3182 - val_loss: 0.3830 - val_mean_absolute_error: 0.3328
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3407 - mean_absolute_error: 0.3121 - val_loss: 0.3860 - val_mean_absolute_error: 0.3358
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3485 - mean_absolute_error: 0.3191 - val_loss: 0.3817 - val_mean_absolute_error: 0.3338
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3365 - mean_absolute_error: 0.3161 - val_loss: 0.3793 - val_mean_absolute_error: 0.3315
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3461 - mean_absolute_error: 0.3175 - val_loss: 0.3805 - val_mean_absolute_error: 0.3324
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3349 - mean_absolute_error: 0.3111 - val_loss: 0.3841 - val_mean_absolute_error: 0.3353
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3561 - mean_absolute_error: 0.3225 - val_loss: 0.3778 - val_mean_absolute_error: 0.3292
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3275 - mean_absolute_error: 0.3084 - val_loss: 0.3826 - val_mean_absolute_error: 0.3349
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3457 - mean_absolute_error: 0.3183 - val_loss: 0.3771 - val_mean_absolute_error: 0.3320
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3585 - mean_absolute_error: 0.3221 - val_loss: 0.3782 - val_mean_absolute_error: 0.3333
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3544 - mean_absolute_error: 0.3201 - val_loss: 0.3756 - val_mean_absolute_error: 0.3295
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3451 - mean_absolute_error: 0.3161 - val_loss: 0.3755 - val_mean_absolute_error: 0.3296
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3362 - mean_absolute_error: 0.3156 - val_loss: 0.3746 - val_mean_absolute_error: 0.3287
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3426 - mean_absolute_error: 0.3183 - val_loss: 0.3756 - val_mean_absolute_error: 0.3296
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3665 - mean_absolute_error: 0.3287 - val_loss: 0.3753 - val_mean_absolute_error: 0.3291
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3269 - mean_absolute_error: 0.3106 - val_loss: 0.3750 - val_mean_absolute_error: 0.3286
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3392 - mean_absolute_error: 0.3155 - val_loss: 0.3744 - val_mean_absolute_error: 0.3276
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3329 - mean_absolute_error: 0.3121 - val_loss: 0.3798 - val_mean_absolute_error: 0.3333
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3425 - mean_absolute_error: 0.3180 - val_loss: 0.3827 - val_mean_absolute_error: 0.3347
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3227 - mean_absolute_error: 0.3086 - val_loss: 0.3749 - val_mean_absolute_error: 0.3305
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3176 - mean_absolute_error: 0.3045 - val_loss: 0.3720 - val_mean_absolute_error: 0.3291
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3364 - mean_absolute_error: 0.3114 - val_loss: 0.3737 - val_mean_absolute_error: 0.3290
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3189 - mean_absolute_error: 0.3056 - val_loss: 0.3743 - val_mean_absolute_error: 0.3298
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3234 - mean_absolute_error: 0.3085 - val_loss: 0.3716 - val_mean_absolute_error: 0.3277
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3110 - mean_absolute_error: 0.3047 - val_loss: 0.3712 - val_mean_absolute_error: 0.3273
# Epoch 67/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3299 - mean_absolute_error: 0.3106 - val_loss: 0.3712 - val_mean_absolute_error: 0.3288
# Epoch 68/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3035 - mean_absolute_error: 0.2991 - val_loss: 0.3696 - val_mean_absolute_error: 0.3265
# Epoch 69/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3080 - mean_absolute_error: 0.3010 - val_loss: 0.3729 - val_mean_absolute_error: 0.3291
# Epoch 70/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3313 - mean_absolute_error: 0.3132 - val_loss: 0.3686 - val_mean_absolute_error: 0.3282
# Epoch 71/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3243 - mean_absolute_error: 0.3104 - val_loss: 0.3703 - val_mean_absolute_error: 0.3281
# Epoch 72/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3239 - mean_absolute_error: 0.3091 - val_loss: 0.3719 - val_mean_absolute_error: 0.3303
# Epoch 73/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3303 - mean_absolute_error: 0.3096 - val_loss: 0.3691 - val_mean_absolute_error: 0.3295
# Epoch 74/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3172 - mean_absolute_error: 0.3062 - val_loss: 0.3688 - val_mean_absolute_error: 0.3289
# Epoch 75/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3138 - mean_absolute_error: 0.3034 - val_loss: 0.3720 - val_mean_absolute_error: 0.3302

# %%
plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ##### The plot now shows a good evolution of the loss value.

# %% [markdown]
# ## How does changing the stucture affect the model?
#
# ##### Along with the loss function, the structure of the CNN can be changed. I suggest seeing what happens when you do the following:
# - `Change the Dense layers to have units=10`
# - `Uncomment the additional MaxPooling2D and Conv2D layers`
# - `Increase Conv2D filters to 64 and 128, respectively`
# - `Change the loss function to mean_absolute_error`
# - `Change the Dense layers to have activation="sigmoid"`
#
# ##### Pay mind to how changing these parameters affect the number of parameters to train, how long training time becomes, and the 2D histogram of actual versus predicted OPGs. Feel free to try your own edits to inspect how it affects the testing outcome.

# %%
model = Sequential([  
    InputLayer(shape=(latitude, longitude, channels)),
    Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 16 to 64
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 32 to 128
    # MaxPooling2D(pool_size = (2,2)),                                                    # <-- Comment in this line
    # Conv2D(filters = 64, kernel_size = (3,3), padding = 'same', activation = 'relu'),   # <-- Comment in this line
    BatchNormalization(),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(.25),
    Flatten(),
    Dense(units = 100, activation = 'sigmoid'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dense(units = 100, activation = 'sigmoid'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dropout(.25),
    Dense(units = len(facet_list), activation = 'linear') ])

model.summary()

model.compile(loss = 'mean_squared_error',          # <-- Change Loss Function Here from mean_squared_error to mean_absolute_error
              metrics = ["mean_absolute_error", "mean_squared_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

epochs = 80

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

hist = model.fit(train_atmos, train_opg, 
                  batch_size = batch_size,
                  epochs = epochs,                      
                  validation_data = (val_atmos, val_opg),
                  callbacks=[callback],
                  verbose = 0)                     # <-- If you want to silence training, set to 0, if you want to watch it train, set to 1

plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# #### Notice the differences between outputs when changing the hyperparameters:
# - `Change the Dense layers to have units=10`:
#   The number of trainable parameters decreases considerably from 95,678 to 13,714. Though the mean squared error reaches a minimum around 80 epochs, the OPG heatmap indicates a decrease in r^2 and an increase in error. Overall, the model is less able to predict more extreme OPGs. Possibiliy from too little parameters?
#
# - `Uncomment the additional MaxPooling2D and Conv2D layers`:
#   Additional MaxPooling2D and Conv2D layers decreased the number of trainable parameters from 95,614 to 75,774. Based on the mean squared error, the model seems to reach a minimum in error somewhere around 60 epochs. The addition of MaxPooling2D and Conv2D layers did not visually improve the OPG predictions.
#
# - `Increase Conv2D filters to 64 and 128 respectively`:
#   Additional Conv2D filters significantly increased the number of trainable parameters from 95,614 to 398,062. Having more filters to identify patterns did not visually improve the mean squared error or the OPG predictions. It did increase the training time of the model, while decreasing the number of epochs. Indicating that more parameters does not mean a better model and can be unnessesary.
#
# - `Change the loss function to mean_absolute_error`:
#   Based on the plot of mean absolute error by epoch, the model tends to train very quickly in the beginning and trains slowly until ending. The OPG heatmap shows OPGs are more underpredicted than when using mean_squared_error, most likely due to the loss function. Mean squared error forces the model to focus more on larger loss values due to thier increased size.
#
# - `Change the Dense layers to have activation="sigmoid"`:
#
#
# #### What you choose for hyperparameters and structure all depends on what your goals are.
