# %% [markdown]
# # CIROH Developers Conference: Hydrological Applications of ML
# ### CNNs for Predicting Daily Orographic Precipitation Gradients (OPGs) for Atmospheric Downscaling

# %% [markdown]
# ## Introduction
#
# In this exercise, we'll build a convolutional neural network (CNN) for regression of orographic precipitation gradients of Northern Utah. Other uses include:
#
# - Image classification
# - Image denoising or reconstruction
#
# But all methods are based around two basic operations:
#
# - Convolution: in this step, the network learns a series of kernels or filters that transform the original image in some way. These are similar to filters that are used in standard image processing (e.g. low-pass filters), but filters are chosen by how well the transformed image maps to the outcome variable. To put this another way, these filters identify shapes or features that are important in differentiating between different outcomes
# - Max-pooling: in this step, the image resolution is transformed. In general, the resolution is halved, by aggregating groups of four pixels in a two by two window.
#
# In general, these steps are repeated several times. As this progresses, the small shapes identified in the first set of convolutions are progressively combined into larger structures. For example, a series of small curves or lines could be aggregated into a cat's eye.

# %% [markdown]
# ## Data processing
# ##### Let's start, as usual, by loading the libraries we'll need for the lab:

# %%
# Data manipulation
import pandas as pd
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt
from matplotlib import colors
import nclcmaps as ncm

# %% [markdown]
# ##### Now we set the path to the data folders and download the datasets. If you have any questions about setting this path, please ask.

# %%
# load in the atmospheric data
path      = "../datasets/era5_atmos/"
IVT       = xr.open_dataset(f"{path}IVT_sfc.nc")
precip    = xr.open_dataset(f"{path}precip_sfc.nc")*1000
temp700   = xr.open_dataset(f"{path}temp_700.nc")-273.15
uwinds700 = xr.open_dataset(f"{path}uwnd_700.nc")
vwinds700 = xr.open_dataset(f"{path}vwnd_700.nc")
hgt500    = xr.open_dataset(f"{path}hgt_500.nc")/9.81

# load in the OPGs
path = "../datasets/facets_and_opgs/"
opg  = pd.read_csv(f"{path}winter_northernUT_opg.csv", index_col=0)
facet_list = opg.columns.values
opg = opg.values

# %% [markdown]
# #### Standardizing the Datasets:
#
# ##### Since the values between the atmospheric variables contain a large variability in scale, we standardize each variable individually. This levels the playing field, so to speak, so that all atmospheric variables are taken into account within the CNN. This also applies to the facet OPGs, as a machine learning model is better equipted predicting values between -1 and 1.
#
# ##### In other cases, you may prefer to normalize the datasets.

# %%
IVT       = (IVT - IVT.mean(dim="time")) / IVT.std(dim="time")
precip    = (precip - precip.mean(dim="time")) / precip.std(dim="time")
temp700   = (temp700 - temp700.mean(dim="time")) / temp700.std(dim="time")
uwinds700 = (uwinds700 - uwinds700.mean(dim="time")) / uwinds700.std(dim="time")
vwinds700 = (vwinds700 - vwinds700.mean(dim="time")) / vwinds700.std(dim="time")
hgt500    = (hgt500 - hgt500.mean(dim="time")) / hgt500.std(dim="time")

opg_mean = np.nanmean(opg, axis=0) # Save OPG mean and standard deviation so that we can
opg_std  = np.nanstd(opg, axis=0)  # convert back to true values from standardized values later on.
opg = (opg - opg_mean) / opg_std

# %% [markdown]
# ##### Unique to the OPG dataset, for days without precipitation, the value within the array are NaNs. However, machine learning algoirthms of this architecture are unable to predict NaN as an output. Therefore, days without observations are set to zero, as it is the average value of the dataset.
#
# ##### In classification tasks, the missing values are often set to a new catagory.

# %%
opg[np.isnan(opg)] = 0

# %% [markdown]
# ##### To input the atmospheric data into the CNN model, the atmospheric variables are combined into one array.

# %%
# Combine the atmospheric data into one array
atmos = np.concatenate((IVT.IVT.values[...,np.newaxis], 
                        precip.precip.values[...,np.newaxis],
                        temp700.temp.values[...,np.newaxis],
                        uwinds700.uwnd.values[...,np.newaxis],
                        vwinds700.vwnd.values[...,np.newaxis],
                        hgt500.hgt.values[...,np.newaxis]), axis=3)
print(np.shape(atmos))
# Out:
# (2708, 19, 27, 6)

# %% [markdown]
# ##### The above output lists the dimensions of all the atmospheric variables combined. It contains 2708 observation days or 'images', with a 19 x 27 grid of latitudes and longitudes. Each atmospheric variable represents a channel, here we have 6 channels.
#
# ##### Channels can be viewed as layers of the image. For example, when using visual images of RGB colors, there would be 3 channels.
#
# ##### CNNs are not limited only to images of shape `(samples, height, width, channels)`, CNNs can be used to evaluate vector data `(samples, features)`, timeseries data `(samples, timesteps, features)`, and video data `(samples, frames, height, width, channels)`.

# %%
latitude  = 19 # height
longitude = 27 # width
channels  = 6  # channel

# %% [markdown]
# ##### When creating a ML model, the datasets are split into training, validation, and testing subsets. The model is trained on the training subset, evaluated on the validation subset, and tested on the testing subset.
#
# ##### These datasets are often randomly shuffled to produce training, validation, and testing subsets. If redundency exists in your dataset, or in our case, multipday precipitation events, it can be important to split the datasets differently. Such as by week, months, or years.
#
# ##### The split of these datasets are user defined, here we'll use a 70/15/15% split.

# %%
np.random.seed(42)
rand_ind = np.random.permutation(np.arange(np.shape(atmos)[0]))

train_atmos = atmos[rand_ind[:1896], ...]
test_atmos  = atmos[rand_ind[1896:2302], ...]
val_atmos   = atmos[rand_ind[2302:], ...]

train_opg = opg[rand_ind[:1896], ...]
test_opg  = opg[rand_ind[1896:2302], ...]
val_opg   = opg[rand_ind[2302:], ...]

print(np.shape(test_atmos))
# Out:
# (406, 19, 27, 6)

# %% [markdown]
# ##### The last parameter we'll set here is the batch size. This parameter controls how many samples are processed in training simultaneously, typically between 8 and 128. The dataset is separated into batches, processed by the model, and the weights within the model are adjusted|. Once all batches are processed, one epoch has been processed.
#
# ##### This also controls how much memory is used per step of training, which is very useful if you're training on a computer with limited memory.

# %%
batch_size = 32

# %% [markdown]
# ## Create CNN Model
#
# ##### Let's now set up the model. As this is quite a complex model, we'll do this as a series of steps rather than in one go. First, import all the modules from Keras that we'll need:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (InputLayer, 
                                      Conv2D,
                                      Dense,
                                      ReLU,LeakyReLU,
                                      BatchNormalization, 
                                      MaxPooling2D, 
                                      Dropout,
                                      Flatten)
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Now, create a template sequential model, this way we can build the model incrementally:

# %%
model = Sequential()

# %% [markdown]
# ##### First, we'll use `InputLayer` to declare the shape of the input data. Notice that we care about the entire input set, not the batch size.

# %%
model.add(InputLayer(shape=(latitude, longitude, channels)))

# %% [markdown]
# ##### Next we add the first hidden layer, `Conv2D`. This is a convolutional layer, where we'll create 16 filters (or convolutions) based on the original images, with a 3x3 kernel. We'll add padding to the input of the `Conv2D` layer, this adds the appropriate number of rows and columns around the input image so that the output image is the `same` height and width.

# %%
model.add(Conv2D(filters = 16, kernel_size = (3,3), padding = 'same'))

# %% [markdown]
# ##### We'll then take the output of this layer and pass it through a `ReLU()` activation function (this could have been included directly in the convolutional layer, but this allows a little more control on the process):

# %%
model.add(ReLU())

# %% [markdown]
# ##### Now, we add a `MaxPooling2D` layer. As a reminder, this reduces the resolution of the output from the previous layer by a simple filter, forcing the next layer of the network to focus on larger image features. We'll also add a `Dropout` layer. This is a form of regularization. It randomly sets some connection weights to 0 (i.e. having no contribution to the model), which can reduce overfitting.

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Let's add another convolutional layer, this time with 32 filters, and pass this through a ReLU activation function.

# %%
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'same'))
model.add(ReLU())

# %% [markdown]
# ##### We'll take the output of this function and normalize the weights. This is a simple method that adjusts the mean weight to close to zero and reduces the amount of variation. This helps avoid gradient problems with very small or very large weights

# %%
model.add(BatchNormalization())

# %% [markdown]
# ##### And we'll run the output of this through a max-pooling function with dropout:

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Now we'll add layers to connect the output of this last `MaxPooling2D` step to the output (the OPGs). The first thing we need to do is to `Flatten()` the output. The output of the max-pooling is a tensor of shape (4, 6, 32). The size of 4x5 is a result of the two max-pooling operations and the 32 is the number of filters from the second convolution. The `Flatten()` function will flatten this into a rank 1 tensor of shape (768).

# %%
model.add(Flatten())

# %% [markdown]
# ##### Next we'll pass this flattened layer through a `Dense()` layer, which are densely conncted neural layers. And then through `ReLU()` activation and a dropout

# %%
model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dropout(.25))

# %% [markdown]
# ##### Finally, we need to output predictions. As this is a regression task, the final layer needs to have the same number of nodes as northern Utah facets, and the output is passed through a linear activation function. Linear activation functions are typically used whe you're trying to predict continuous values.

# %%
model.add(Dense(units = len(facet_list), activation = 'linear'))

# %% [markdown]
# ##### More practically, we'll create a function that will build the model in one go. This will allow us to easily create new versions for testing.

# %%
def create_model():
    model = Sequential([  
        InputLayer(shape=(latitude, longitude, channels)),
        Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'),
        MaxPooling2D(pool_size = (2,2)),
        Dropout(.25),
        Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size = (2,2)),
        Dropout(.25),
        Flatten(),
        Dense(units = 100, activation = 'relu'),
        Dense(units = 100, activation = 'relu'),
        Dropout(.25),
        Dense(units = len(facet_list), activation = 'linear')
    ])
    return model

# %% [markdown]
# ##### Let's take a look at the whole thing:

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_42 (Conv2D)              │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_42 (MaxPooling2D) │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_43 (MaxPooling2D) │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)

# %% [markdown]
# ##### Our model has a little over 95,000 parameters or weights to train (hence the need for a lot of images). Note that there are small set of non-trainable parameter from the normalization layer.
#
# ##### We can also generate a simple visualization:

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# ##### The next step is to compile the model. This is an optimization function, a loss function and performance metric. A good option for the loss function in a regression problem is `mean_squared_error`, metrics allows the user to add aditional functions to monitor training. The optimizer implements the agorithmn which updates the weights of the model.

# %%
model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop())

# %% [markdown]
# ## Training the model
#
# ##### We'll now train the model for 50 epochs using the `fit()` method upon our built model. We specify:
#
# - `train_atmos`: The training subset of the atmospheric variables
# - `train_opg`: The training subset of the observed OPGs
# - `batch_size`: The number of samples or observation days used per gradient update.
# - `epochs`: The number of full training iterations.
# - `validation_data`: The validation subset of the atmospheric variables and observed OPGs
#
# ##### This takes a few minutes to train (on my laptop). It's worth remembering what is going on here: the algorithm is reading in batches of 32 images, rescaling them, updating model weights through back propagation and then repeating the whole thing 50 times. As we previously defined a separate validation subset, this routine will calculate two losses:
# - The training loss. This is how accurately the model can predict OPG from the atmospheric 'images' that are being used to update the weights
# - The validation loss. This is how accurately the model can predict OPG from a set of atmospheric 'images' that are not used in updating the weights
#
# ##### As the model continues to train, you should see the loss decrease for both of these, but will likely stabilize at a certain point.

# %%
epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0441 - mean_absolute_error: 0.6259 - val_loss: 0.4824 - val_mean_absolute_error: 0.3345
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4305 - mean_absolute_error: 0.3525 - val_loss: 0.4572 - val_mean_absolute_error: 0.3294
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4148 - mean_absolute_error: 0.3486 - val_loss: 0.4167 - val_mean_absolute_error: 0.3233
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4167 - mean_absolute_error: 0.3449 - val_loss: 0.4042 - val_mean_absolute_error: 0.3175
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3631 - mean_absolute_error: 0.3242 - val_loss: 0.3723 - val_mean_absolute_error: 0.3203
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3589 - mean_absolute_error: 0.3236 - val_loss: 0.3926 - val_mean_absolute_error: 0.3179
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3505 - mean_absolute_error: 0.3180 - val_loss: 0.3667 - val_mean_absolute_error: 0.3138
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3750 - mean_absolute_error: 0.3209 - val_loss: 0.3699 - val_mean_absolute_error: 0.3208
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3557 - mean_absolute_error: 0.3216 - val_loss: 0.3668 - val_mean_absolute_error: 0.3146
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3290 - mean_absolute_error: 0.3090 - val_loss: 0.3607 - val_mean_absolute_error: 0.3215
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3408 - mean_absolute_error: 0.3151 - val_loss: 0.3656 - val_mean_absolute_error: 0.3220
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3159 - mean_absolute_error: 0.3020 - val_loss: 0.3611 - val_mean_absolute_error: 0.3199
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3221 - mean_absolute_error: 0.3031 - val_loss: 0.3679 - val_mean_absolute_error: 0.3121
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3347 - mean_absolute_error: 0.3088 - val_loss: 0.3536 - val_mean_absolute_error: 0.3150
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3256 - mean_absolute_error: 0.3084 - val_loss: 0.3677 - val_mean_absolute_error: 0.3138
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3366 - mean_absolute_error: 0.3057 - val_loss: 0.3513 - val_mean_absolute_error: 0.3126
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3032 - mean_absolute_error: 0.2977 - val_loss: 0.3583 - val_mean_absolute_error: 0.3228
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3186 - mean_absolute_error: 0.3021 - val_loss: 0.3431 - val_mean_absolute_error: 0.3091
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3227 - mean_absolute_error: 0.3021 - val_loss: 0.3560 - val_mean_absolute_error: 0.3113
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2979 - mean_absolute_error: 0.2936 - val_loss: 0.3476 - val_mean_absolute_error: 0.3153
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2977 - mean_absolute_error: 0.2954 - val_loss: 0.3499 - val_mean_absolute_error: 0.3200
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2963 - mean_absolute_error: 0.2973 - val_loss: 0.3435 - val_mean_absolute_error: 0.3104
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2960 - mean_absolute_error: 0.2917 - val_loss: 0.3460 - val_mean_absolute_error: 0.3151
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3058 - mean_absolute_error: 0.2991 - val_loss: 0.3511 - val_mean_absolute_error: 0.3130
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2888 - mean_absolute_error: 0.2881 - val_loss: 0.3531 - val_mean_absolute_error: 0.3156
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2960 - mean_absolute_error: 0.2932 - val_loss: 0.3429 - val_mean_absolute_error: 0.3118
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2914 - mean_absolute_error: 0.2902 - val_loss: 0.3528 - val_mean_absolute_error: 0.3213
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3003 - mean_absolute_error: 0.2970 - val_loss: 0.3461 - val_mean_absolute_error: 0.3167
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2928 - mean_absolute_error: 0.2968 - val_loss: 0.3513 - val_mean_absolute_error: 0.3169
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3108 - mean_absolute_error: 0.3027 - val_loss: 0.3495 - val_mean_absolute_error: 0.3157
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3020 - mean_absolute_error: 0.2988 - val_loss: 0.3497 - val_mean_absolute_error: 0.3162
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2933 - mean_absolute_error: 0.2925 - val_loss: 0.3671 - val_mean_absolute_error: 0.3179
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2880 - mean_absolute_error: 0.2895 - val_loss: 0.3537 - val_mean_absolute_error: 0.3167
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2568 - mean_absolute_error: 0.2790 - val_loss: 0.3430 - val_mean_absolute_error: 0.3144
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2743 - mean_absolute_error: 0.2861 - val_loss: 0.3407 - val_mean_absolute_error: 0.3133
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2919 - mean_absolute_error: 0.2900 - val_loss: 0.3525 - val_mean_absolute_error: 0.3156
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2808 - mean_absolute_error: 0.2909 - val_loss: 0.3501 - val_mean_absolute_error: 0.3128
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2839 - mean_absolute_error: 0.2924 - val_loss: 0.3417 - val_mean_absolute_error: 0.3110
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2749 - mean_absolute_error: 0.2833 - val_loss: 0.3352 - val_mean_absolute_error: 0.3105
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2585 - mean_absolute_error: 0.2811 - val_loss: 0.3485 - val_mean_absolute_error: 0.3136
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2811 - mean_absolute_error: 0.2897 - val_loss: 0.3501 - val_mean_absolute_error: 0.3145
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2711 - mean_absolute_error: 0.2836 - val_loss: 0.3607 - val_mean_absolute_error: 0.3232
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2708 - mean_absolute_error: 0.2837 - val_loss: 0.3547 - val_mean_absolute_error: 0.3224
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2532 - mean_absolute_error: 0.2795 - val_loss: 0.3569 - val_mean_absolute_error: 0.3127
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2763 - mean_absolute_error: 0.2856 - val_loss: 0.3462 - val_mean_absolute_error: 0.3169
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2806 - mean_absolute_error: 0.2902 - val_loss: 0.3553 - val_mean_absolute_error: 0.3212
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2736 - mean_absolute_error: 0.2884 - val_loss: 0.3507 - val_mean_absolute_error: 0.3203
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2725 - mean_absolute_error: 0.2848 - val_loss: 0.3444 - val_mean_absolute_error: 0.3098
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2539 - mean_absolute_error: 0.2749 - val_loss: 0.3504 - val_mean_absolute_error: 0.3082
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2627 - mean_absolute_error: 0.2830 - val_loss: 0.3388 - val_mean_absolute_error: 0.3122
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2569 - mean_absolute_error: 0.2762 - val_loss: 0.3481 - val_mean_absolute_error: 0.3146
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2696 - mean_absolute_error: 0.2841 - val_loss: 0.3515 - val_mean_absolute_error: 0.3152
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2496 - mean_absolute_error: 0.2762 - val_loss: 0.3455 - val_mean_absolute_error: 0.3109
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2571 - mean_absolute_error: 0.2766 - val_loss: 0.3448 - val_mean_absolute_error: 0.3165
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2553 - mean_absolute_error: 0.2779 - val_loss: 0.3499 - val_mean_absolute_error: 0.3146
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2503 - mean_absolute_error: 0.2760 - val_loss: 0.3406 - val_mean_absolute_error: 0.3093
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2580 - mean_absolute_error: 0.2798 - val_loss: 0.3446 - val_mean_absolute_error: 0.3107
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2475 - mean_absolute_error: 0.2742 - val_loss: 0.3494 - val_mean_absolute_error: 0.3206
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2466 - mean_absolute_error: 0.2744 - val_loss: 0.3509 - val_mean_absolute_error: 0.3149
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2507 - mean_absolute_error: 0.2767 - val_loss: 0.3570 - val_mean_absolute_error: 0.3143
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2345 - mean_absolute_error: 0.2702 - val_loss: 0.3543 - val_mean_absolute_error: 0.3112
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2283 - mean_absolute_error: 0.2680 - val_loss: 0.3511 - val_mean_absolute_error: 0.3123
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2415 - mean_absolute_error: 0.2707 - val_loss: 0.3596 - val_mean_absolute_error: 0.3148
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2379 - mean_absolute_error: 0.2702 - val_loss: 0.3480 - val_mean_absolute_error: 0.3120
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2443 - mean_absolute_error: 0.2718 - val_loss: 0.3497 - val_mean_absolute_error: 0.3174
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2383 - mean_absolute_error: 0.2708 - val_loss: 0.3506 - val_mean_absolute_error: 0.3117
# Epoch 67/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2318 - mean_absolute_error: 0.2674 - val_loss: 0.3478 - val_mean_absolute_error: 0.3121
# Epoch 68/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2384 - mean_absolute_error: 0.2708 - val_loss: 0.3474 - val_mean_absolute_error: 0.3135
# Epoch 69/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2384 - mean_absolute_error: 0.2695 - val_loss: 0.3552 - val_mean_absolute_error: 0.3240
# Epoch 70/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2351 - mean_absolute_error: 0.2694 - val_loss: 0.3419 - val_mean_absolute_error: 0.3118
# Epoch 71/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2286 - mean_absolute_error: 0.2642 - val_loss: 0.3460 - val_mean_absolute_error: 0.3118
# Epoch 72/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2469 - mean_absolute_error: 0.2768 - val_loss: 0.3503 - val_mean_absolute_error: 0.3147
# Epoch 73/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2321 - mean_absolute_error: 0.2678 - val_loss: 0.3498 - val_mean_absolute_error: 0.3201
# Epoch 74/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2308 - mean_absolute_error: 0.2678 - val_loss: 0.3458 - val_mean_absolute_error: 0.3164
# Epoch 75/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2251 - mean_absolute_error: 0.2632 - val_loss: 0.3499 - val_mean_absolute_error: 0.3163
# Epoch 76/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2342 - mean_absolute_error: 0.2712 - val_loss: 0.3523 - val_mean_absolute_error: 0.3159
# Epoch 77/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2282 - mean_absolute_error: 0.2650 - val_loss: 0.3487 - val_mean_absolute_error: 0.3146
# Epoch 78/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2225 - mean_absolute_error: 0.2663 - val_loss: 0.3452 - val_mean_absolute_error: 0.3082
# Epoch 79/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2245 - mean_absolute_error: 0.2650 - val_loss: 0.3530 - val_mean_absolute_error: 0.3123
# Epoch 80/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2208 - mean_absolute_error: 0.2605 - val_loss: 0.3496 - val_mean_absolute_error: 0.3141

# %% [markdown]
# ##### Now plot the evolution of the loss function and the actual versus predicted OPGs:

# %%
def plot_loss(hist_obs):
    plt.plot(hist_obs.history['loss'], label='train')
    plt.plot(hist_obs.history['val_loss'], label='valid')
    plt.xlabel("Epochs", fontsize=label_size)
    plt.ylabel("Mean Squared Error", fontsize=label_size)
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()
    plt.show()

def plot_act_pred(modelx, hist_obs):
    # Using our fitted model, predict OPGs from the testing subset.
    predicted = modelx.predict(test_atmos)

    # set zero OPGs to nan
    actual = test_opg
    actual[actual==0] = np.nan
    predicted[predicted==0] = np.nan
    
    # Convert from standardized OPG to mm/m OPG
    actual    = (test_opg * opg_std) + opg_mean
    predicted = (predicted * opg_std) + opg_mean
    
    # Lets reshape our OPGs and remove NaN OPG days
    actual    = np.reshape(actual, -1)
    predicted = np.reshape(predicted, -1)
    idx       = np.isnan(actual) # Identify days with OPG observations
    actual    = actual[idx==False]
    predicted = predicted[idx==False]
    
    # Formulate the x and y axis limits
    max_val = np.max((np.max(predicted[:]), np.max(actual[:])))
    min_val = np.min((np.min(predicted[:]), np.min(actual[:])))
    max_val = 0.05
    min_val = -0.05
    
    # Define plot colormap
    cmap_gnuplot2 = ncm.cmap("MPL_gnuplot2")
    
    # Define label sizes
    label_size = 14
    tick_size = 12
    
    # Create Figure
    plt.figure(figsize=(6, 5))
    
    # Formulate the heatmap variables
    heatmap, xedges, yedges = np.histogram2d(np.reshape(actual, -1), np.reshape(predicted, -1), bins=100,
                                 range=[[min_val, max_val],[min_val, max_val]])
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

    # Plot heatmap
    plt.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap_gnuplot2, norm=colors.LogNorm())

    # Plot One-to-one line
    plt.plot([xedges[0], xedges[-1]], [yedges[0], yedges[-1]], c='red')

    # corr
    corr = np.round(np.corrcoef(actual, predicted)[0,1]**2 , 2)
    last_mse = np.round(hist_obs.history['val_loss'][-1], 2)
    
    # Add labels, gridlines, and colorbar
    plt.xlabel("Actual", fontsize=label_size)
    plt.ylabel("Predicted", fontsize=label_size)
    plt.title("r^2 = " + str(corr) + ", Error = " + str(last_mse))
    plt.grid(True)
    plt.colorbar()


plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ##### The plot shows a steep decline in both loss values, but no real improvement beyond epoch 20. It's quite likely that this model has overfit - become too tuned to the training data to allow prediction. There are a variety of ways we can avoid this, but a simple one is to slow the rate at which the model learns. We'll refit the model, but will add a `learning_rate` parameter to the compilation step.
#
# ##### Additionally, `callbacks` can be added to the fitting process, in which the fit algorithm will monitor the validation loss. Here, when the validation loss does not improve after 5 epochs, the model stops training.

# %%
model = create_model()

model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  callbacks=[callback],                   # patience
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.4800 - mean_absolute_error: 1.1091 - val_loss: 0.5147 - val_mean_absolute_error: 0.3751
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8267 - mean_absolute_error: 0.6239 - val_loss: 0.5078 - val_mean_absolute_error: 0.3607
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6111 - mean_absolute_error: 0.5009 - val_loss: 0.5012 - val_mean_absolute_error: 0.3559
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5121 - mean_absolute_error: 0.4390 - val_loss: 0.4924 - val_mean_absolute_error: 0.3558
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4957 - mean_absolute_error: 0.4184 - val_loss: 0.4817 - val_mean_absolute_error: 0.3569
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5242 - mean_absolute_error: 0.4123 - val_loss: 0.4713 - val_mean_absolute_error: 0.3572
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4857 - mean_absolute_error: 0.3983 - val_loss: 0.4589 - val_mean_absolute_error: 0.3563
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4600 - mean_absolute_error: 0.3876 - val_loss: 0.4481 - val_mean_absolute_error: 0.3564
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4356 - mean_absolute_error: 0.3760 - val_loss: 0.4376 - val_mean_absolute_error: 0.3542
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4440 - mean_absolute_error: 0.3768 - val_loss: 0.4271 - val_mean_absolute_error: 0.3521
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4066 - mean_absolute_error: 0.3585 - val_loss: 0.4186 - val_mean_absolute_error: 0.3490
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4119 - mean_absolute_error: 0.3622 - val_loss: 0.4141 - val_mean_absolute_error: 0.3479
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4332 - mean_absolute_error: 0.3677 - val_loss: 0.4104 - val_mean_absolute_error: 0.3457
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4392 - mean_absolute_error: 0.3714 - val_loss: 0.4032 - val_mean_absolute_error: 0.3399
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3901 - mean_absolute_error: 0.3507 - val_loss: 0.3991 - val_mean_absolute_error: 0.3379
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4033 - mean_absolute_error: 0.3509 - val_loss: 0.3935 - val_mean_absolute_error: 0.3385
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4027 - mean_absolute_error: 0.3549 - val_loss: 0.3909 - val_mean_absolute_error: 0.3371
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3744 - mean_absolute_error: 0.3436 - val_loss: 0.3897 - val_mean_absolute_error: 0.3355
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3778 - mean_absolute_error: 0.3421 - val_loss: 0.3887 - val_mean_absolute_error: 0.3346
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3911 - mean_absolute_error: 0.3422 - val_loss: 0.3850 - val_mean_absolute_error: 0.3325
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4139 - mean_absolute_error: 0.3552 - val_loss: 0.3836 - val_mean_absolute_error: 0.3315
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3597 - mean_absolute_error: 0.3301 - val_loss: 0.3841 - val_mean_absolute_error: 0.3326
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3722 - mean_absolute_error: 0.3403 - val_loss: 0.3828 - val_mean_absolute_error: 0.3298
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3555 - mean_absolute_error: 0.3297 - val_loss: 0.3841 - val_mean_absolute_error: 0.3330
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3746 - mean_absolute_error: 0.3395 - val_loss: 0.3779 - val_mean_absolute_error: 0.3276
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3715 - mean_absolute_error: 0.3314 - val_loss: 0.3757 - val_mean_absolute_error: 0.3279
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3746 - mean_absolute_error: 0.3332 - val_loss: 0.3742 - val_mean_absolute_error: 0.3246
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3847 - mean_absolute_error: 0.3370 - val_loss: 0.3740 - val_mean_absolute_error: 0.3252
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3880 - mean_absolute_error: 0.3396 - val_loss: 0.3733 - val_mean_absolute_error: 0.3250
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3670 - mean_absolute_error: 0.3306 - val_loss: 0.3707 - val_mean_absolute_error: 0.3236
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3665 - mean_absolute_error: 0.3325 - val_loss: 0.3696 - val_mean_absolute_error: 0.3231
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3549 - mean_absolute_error: 0.3264 - val_loss: 0.3695 - val_mean_absolute_error: 0.3227
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3871 - mean_absolute_error: 0.3383 - val_loss: 0.3679 - val_mean_absolute_error: 0.3220
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3702 - mean_absolute_error: 0.3349 - val_loss: 0.3671 - val_mean_absolute_error: 0.3230
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3686 - mean_absolute_error: 0.3317 - val_loss: 0.3671 - val_mean_absolute_error: 0.3224
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3427 - mean_absolute_error: 0.3189 - val_loss: 0.3663 - val_mean_absolute_error: 0.3211
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3521 - mean_absolute_error: 0.3252 - val_loss: 0.3670 - val_mean_absolute_error: 0.3229
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3635 - mean_absolute_error: 0.3280 - val_loss: 0.3648 - val_mean_absolute_error: 0.3219
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3150 - mean_absolute_error: 0.3105 - val_loss: 0.3644 - val_mean_absolute_error: 0.3213
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3493 - mean_absolute_error: 0.3238 - val_loss: 0.3656 - val_mean_absolute_error: 0.3216
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3422 - mean_absolute_error: 0.3177 - val_loss: 0.3638 - val_mean_absolute_error: 0.3211
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3548 - mean_absolute_error: 0.3236 - val_loss: 0.3636 - val_mean_absolute_error: 0.3219
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3250 - mean_absolute_error: 0.3117 - val_loss: 0.3628 - val_mean_absolute_error: 0.3206
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3370 - mean_absolute_error: 0.3169 - val_loss: 0.3623 - val_mean_absolute_error: 0.3188
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3683 - mean_absolute_error: 0.3260 - val_loss: 0.3644 - val_mean_absolute_error: 0.3215
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3517 - mean_absolute_error: 0.3190 - val_loss: 0.3647 - val_mean_absolute_error: 0.3213
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3465 - mean_absolute_error: 0.3186 - val_loss: 0.3633 - val_mean_absolute_error: 0.3209
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3395 - mean_absolute_error: 0.3165 - val_loss: 0.3635 - val_mean_absolute_error: 0.3199
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3337 - mean_absolute_error: 0.3177 - val_loss: 0.3615 - val_mean_absolute_error: 0.3180
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3315 - mean_absolute_error: 0.3088 - val_loss: 0.3615 - val_mean_absolute_error: 0.3201
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3658 - mean_absolute_error: 0.3245 - val_loss: 0.3592 - val_mean_absolute_error: 0.3177
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3480 - mean_absolute_error: 0.3249 - val_loss: 0.3610 - val_mean_absolute_error: 0.3199
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3270 - mean_absolute_error: 0.3150 - val_loss: 0.3602 - val_mean_absolute_error: 0.3186
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3270 - mean_absolute_error: 0.3105 - val_loss: 0.3590 - val_mean_absolute_error: 0.3177
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3369 - mean_absolute_error: 0.3142 - val_loss: 0.3585 - val_mean_absolute_error: 0.3184
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3477 - mean_absolute_error: 0.3190 - val_loss: 0.3575 - val_mean_absolute_error: 0.3187
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3415 - mean_absolute_error: 0.3153 - val_loss: 0.3568 - val_mean_absolute_error: 0.3187
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3271 - mean_absolute_error: 0.3103 - val_loss: 0.3562 - val_mean_absolute_error: 0.3190
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3077 - mean_absolute_error: 0.3029 - val_loss: 0.3552 - val_mean_absolute_error: 0.3179
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3264 - mean_absolute_error: 0.3131 - val_loss: 0.3564 - val_mean_absolute_error: 0.3175
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3425 - mean_absolute_error: 0.3166 - val_loss: 0.3549 - val_mean_absolute_error: 0.3174
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3454 - mean_absolute_error: 0.3199 - val_loss: 0.3560 - val_mean_absolute_error: 0.3157
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3075 - mean_absolute_error: 0.3014 - val_loss: 0.3568 - val_mean_absolute_error: 0.3186
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3239 - mean_absolute_error: 0.3113 - val_loss: 0.3576 - val_mean_absolute_error: 0.3160
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3540 - mean_absolute_error: 0.3188 - val_loss: 0.3566 - val_mean_absolute_error: 0.3165
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3177 - mean_absolute_error: 0.3026 - val_loss: 0.3557 - val_mean_absolute_error: 0.3183

# %%
plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ##### The plot now shows a good evolution of the loss value.

# %% [markdown]
# ## How does changing the stucture affect the model?
#
# ##### Along with the loss function, the structure of the CNN can be changed. I suggest seeing what happens when you do the following:
# - `Change the Dense layers to have units=10`
# - `Uncomment the additional MaxPooling2D and Conv2D layers`
# - `Increase Conv2D filters to 64 and 128, respectively`
# - `Change the loss function to mean_absolute_error`
# - `Change the Dense layers to have activation="sigmoid"`
#
# ##### Pay mind to how changing these parameters affect the number of parameters to train, how long training time becomes, and the 2D histogram of actual versus predicted OPGs. Feel free to try your own edits to inspect how it affects the testing outcome.

# %%
model = Sequential([  
    InputLayer(shape=(latitude, longitude, channels)),
    Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 16 to 64
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 32 to 128
    # MaxPooling2D(pool_size = (2,2)),                                                    # <-- Comment in this line
    # Conv2D(filters = 64, kernel_size = (3,3), padding = 'same', activation = 'relu'),   # <-- Comment in this line
    BatchNormalization(),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(.25),
    Flatten(),
    Dense(units = 100, activation = 'sigmoid'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dense(units = 100, activation = 'sigmoid'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dropout(.25),
    Dense(units = len(facet_list), activation = 'linear') ])

model.summary()

model.compile(loss = 'mean_squared_error',          # <-- Change Loss Function Here from mean_squared_error to mean_absolute_error
              metrics = ["mean_absolute_error", "mean_squared_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

epochs = 80

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

hist = model.fit(train_atmos, train_opg, 
                  batch_size = batch_size,
                  epochs = epochs,                      
                  validation_data = (val_atmos, val_opg),
                  callbacks=[callback],
                  verbose = 0)                     # <-- If you want to silence training, set to 0, if you want to watch it train, set to 1

plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_63 (Conv2D)              │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_63 (MaxPooling2D) │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_64 (Conv2D)              │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_64 (MaxPooling2D) │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_71 (Dropout)            │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_29 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_72 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_89 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# #### Notice the differences between outputs when changing the hyperparameters:
# - `Change the Dense layers to have units=10`:
#   The number of trainable parameters decreases considerably from 95,678 to 13,714. Though the mean squared error reaches a minimum around 80 epochs, the OPG heatmap indicates a decrease in r^2 and an increase in error. Overall, the model is less able to predict more extreme OPGs. Possibiliy from too little parameters?
#
# - `Uncomment the additional MaxPooling2D and Conv2D layers`:
#   Additional MaxPooling2D and Conv2D layers decreased the number of trainable parameters from 95,614 to 75,774. Based on the mean squared error, the model seems to reach a minimum in error somewhere around 60 epochs. The addition of MaxPooling2D and Conv2D layers did not visually improve the OPG predictions.
#
# - `Increase Conv2D filters to 64 and 128 respectively`:
#   Additional Conv2D filters significantly increased the number of trainable parameters from 95,614 to 398,062. Having more filters to identify patterns did not visually improve the mean squared error or the OPG predictions. It did increase the training time of the model, while decreasing the number of epochs. Indicating that more parameters does not mean a better model and can be unnessesary.
#
# - `Change the loss function to mean_absolute_error`:
#   Based on the plot of mean absolute error by epoch, the model tends to train very quickly in the beginning and trains slowly until ending. The OPG heatmap shows OPGs are more underpredicted than when using mean_squared_error, most likely due to the loss function. Mean squared error forces the model to focus more on larger loss values due to thier increased size.
#
# - `Change the Dense layers to have activation="sigmoid"`:
#
#
# #### What you choose for hyperparameters and structure all depends on what your goals are.
