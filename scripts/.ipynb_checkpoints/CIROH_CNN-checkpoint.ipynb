# %% [markdown]
# # CIROH Developers Conference: Hydrological Applications of ML
# ## CNNs for Predicting Daily Orographic Precipitation Gradients (OPGs) for Atmospheric Downscaling

# %% [markdown]
# # Introduction
#
# In this exercise, we'll build a convolutional neural network (CNN) for regression of orographic precipitation gradients of Northern Utah. Other uses include:
#
# - Image classification
# - Image denoising or reconstruction
#
# But all methods are based around two basic operations:
#
# - Convolution: in this step, the network learns a series of kernels or filters that transform the original image in some way. These are similar to filters that are used in standard image processing (e.g. low-pass filters), but filters are chosen by how well the transformed image maps to the outcome variable. To put this another way, these filters identify shapes or features that are important in differentiating between different outcomes
# - Max-pooling: in this step, the image resolution is transformed. In general, the resolution is halved, by aggregating groups of four pixels in a two by two window.
#
# In general, these steps are repeated several times. As this progresses, the small shapes identified in the first set of convolutions are progressively combined into larger structures. For example, a series of small curves or lines could be aggregated into a cat's eye.

# %% [markdown]
# ## OPG Regression
#
# ### Data processing
# ##### Let's start, as usual, by loading the libraries we'll need for the lab:

# %%
# Data manipulation
import pandas as pd
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt
from matplotlib import colors
import nclcmaps as ncm

# %% [markdown]
# ##### Now we set the path to the data folders and download the datasets. If you have any questions about setting this path, please ask.

# %%
# load in the atmospheric data
path      = "../datasets/era5_atmos/"
IVT       = xr.open_dataset(f"{path}IVT_sfc.nc")
precip    = xr.open_dataset(f"{path}precip_sfc.nc")*1000
temp700   = xr.open_dataset(f"{path}temp_700.nc")-273.15
uwinds700 = xr.open_dataset(f"{path}uwnd_700.nc")
vwinds700 = xr.open_dataset(f"{path}vwnd_700.nc")
hgt500    = xr.open_dataset(f"{path}hgt_500.nc")/9.81

# load in the OPGs
path = "../datasets/facets_and_opgs/"
opg  = pd.read_csv(f"{path}winter_northernUT_opg.csv", index_col=0)
facet_list = opg.columns.values
opg = opg.values

# %% [markdown]
# ##### Standardizing the Datasets:
#
# ##### Since the values between the atmospheric variables contain a large variability in scale, we standardize each variable individually. This levels the playing field, so to speak, so that all atmospheric variables are taken into account within the CNN. This also applies to the facet OPGs, as a machine learning model is better equipted predicting values between -1 and 1.
#
# ##### In other cases, you may prefer to normalize the datasets.

# %%
IVT       = (IVT - IVT.mean(dim="time")) / IVT.std(dim="time")
precip    = (precip - precip.mean(dim="time")) / precip.std(dim="time")
temp700   = (temp700 - temp700.mean(dim="time")) / temp700.std(dim="time")
uwinds700 = (uwinds700 - uwinds700.mean(dim="time")) / uwinds700.std(dim="time")
vwinds700 = (vwinds700 - vwinds700.mean(dim="time")) / vwinds700.std(dim="time")
hgt500    = (hgt500 - hgt500.mean(dim="time")) / hgt500.std(dim="time")

opg_mean = np.nanmean(opg, axis=0) # Save OPG mean and standard deviation so that we can
opg_std  = np.nanstd(opg, axis=0)  # convert back to true values from standardized values later on.
opg = (opg - opg_mean) / opg_std

# %% [markdown]
# ##### Unique to the OPG dataset, for days without precipitation, the value within the array are NaNs. However, machine learning algoirthms of this architecture are unable to predict NaN as an output. Therefore, days without observations are set to zero, as it is the average value of the dataset.
#
# ##### In classification tasks, the missing values are often set to a new catagory.

# %%
opg[np.isnan(opg)] = 0

# %% [markdown]
# ##### To input the atmospheric data into the CNN model, the atmospheric variables are combined into one array.

# %%
# Combine the atmospheric data into one array
atmos = np.concatenate((IVT.IVT.values[...,np.newaxis], 
                        precip.precip.values[...,np.newaxis],
                        temp700.temp.values[...,np.newaxis],
                        uwinds700.uwnd.values[...,np.newaxis],
                        vwinds700.vwnd.values[...,np.newaxis],
                        hgt500.hgt.values[...,np.newaxis]), axis=3)
print(np.shape(atmos))
# Out:
# (2708, 19, 27, 6)

# %% [markdown]
# ##### The above output lists the dimensions of all the atmospheric variables combined. It contains 2708 observation days or 'images', with a 19 x 27 grid of latitudes and longitudes. Each atmospheric variable represents a channel, here we have 6 channels.
#
# ##### Channels can be viewed as layers of the image. For example, when using visual images of RGB colors, there would be 3 channels.
#
# ##### CNNs are not limited only to images of shape `(samples, height, width, channels)`, CNNs can be used to evaluate vector data `(samples, features)`, timeseries data `(samples, timesteps, features)`, and video data `(samples, frames, height, width, channels)`.

# %%
latitude  = 19 # height
longitude = 27 # width
channels  = 6  # channel

# %% [markdown]
# ##### When creating a ML model, the datasets are split into training, validation, and testing subsets. The model is trained on the training subset, evaluated on the validation subset, and tested on the testing subset.
#
# ##### These datasets are often randomly shuffled to produce training, validation, and testing subsets. If redundency exists in your dataset, or in our case, multipday precipitation events, it can be important to split the datasets differently. Such as by week, months, or years.
#
# ##### The split of these datasets are user defined, here we'll use a 70/15/15% split.

# %%
np.random.seed(42)
rand_ind = np.random.permutation(np.arange(np.shape(atmos)[0]))

train_atmos = atmos[rand_ind[:1896], ...]
test_atmos  = atmos[rand_ind[1896:2302], ...]
val_atmos   = atmos[rand_ind[2302:], ...]

train_opg = opg[rand_ind[:1896], ...]
test_opg  = opg[rand_ind[1896:2302], ...]
val_opg   = opg[rand_ind[2302:], ...]

print(np.shape(test_atmos))
# Out:
# (406, 19, 27, 6)

# %% [markdown]
# ##### The last parameter we'll set here is the batch size. This parameter controls how many samples are processed in training simultaneously, typically between 8 and 128. The dataset is separated into batches, processed by the model, and the weights within the model are adjusted|. Once all batches are processed, one epoch has been processed.
#
# ##### This also controls how much memory is used per step of training, which is very useful if you're training on a computer with limited memory.

# %%
batch_size = 32

# %% [markdown]
# ### Model definition
#
# ##### Let's now set up the model. As this is quite a complex model, we'll do this as a series of steps rather than in one go. First, import all the modules from Keras that we'll need:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (InputLayer, 
                                      Conv2D,
                                      Dense,
                                      ReLU,LeakyReLU,
                                      BatchNormalization, 
                                      MaxPooling2D, 
                                      Dropout,
                                      Flatten)
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Now, create a template sequential model, this way we can build the model incrementally:

# %%
model = Sequential()

# %% [markdown]
# ##### First, we'll use `InputLayer` to declare the shape of the input data. Notice that we care about the entire input set, not the batch size.

# %%
model.add(InputLayer(shape=(latitude, longitude, channels)))

# %% [markdown]
# ##### Next we add the first hidden layer, `Conv2D`. This is a convolutional layer, where we'll create 16 filters (or convolutions) based on the original images, with a 3x3 kernel. We'll add padding to the input of the `Conv2D` layer, this adds the appropriate number of rows and columns around the input image so that the output image is the `same` height and width.

# %%
model.add(Conv2D(filters = 16, kernel_size = (3,3), padding = 'same'))

# %% [markdown]
# ##### We'll then take the output of this layer and pass it through a `ReLU()` activation function (this could have been included directly in the convolutional layer, but this allows a little more control on the process):

# %%
model.add(ReLU())

# %% [markdown]
# ##### Now, we add a `MaxPooling2D` layer. As a reminder, this reduces the resolution of the output from the previous layer by a simple filter, forcing the next layer of the network to focus on larger image features. We'll also add a `Dropout` layer. This is a form of regularization. It randomly sets some connection weights to 0 (i.e. having no contribution to the model), which can reduce overfitting.

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Let's add another convolutional layer, this time with 32 filters, and pass this through a ReLU activation function.

# %%
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'same'))
model.add(ReLU())

# %% [markdown]
# ##### We'll take the output of this function and normalize the weights. This is a simple method that adjusts the mean weight to close to zero and reduces the amount of variation. This helps avoid gradient problems with very small or very large weights

# %%
model.add(BatchNormalization())

# %% [markdown]
# ##### And we'll run the output of this through a max-pooling function with dropout:

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(.25))

# %% [markdown]
# ##### Now we'll add layers to connect the output of this last `MaxPooling2D` step to the output (the OPGs). The first thing we need to do is to `Flatten()` the output. The output of the max-pooling is a tensor of shape (4, 6, 32). The size of 4x5 is a result of the two max-pooling operations and the 32 is the number of filters from the second convolution. The `Flatten()` function will flatten this into a rank 1 tensor of shape (768).

# %%
model.add(Flatten())

# %% [markdown]
# ##### Next we'll pass this flattened layer through a `Dense()` layer, which are densely conncted neural layers. And then through `ReLU()` activation and a dropout

# %%
model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dense(units = 100))
model.add(ReLU())

model.add(Dropout(.25))

# %% [markdown]
# ##### Finally, we need to output predictions. As this is a regression task, the final layer needs to have the same number of nodes as northern Utah facets, and the output is passed through a linear activation function. Linear activation functions are typically used whe you're trying to predict continuous values.

# %%
model.add(Dense(units = len(facet_list), activation = 'linear'))

# %% [markdown]
# ##### More practically, we'll create a function that will build the model in one go. This will allow us to easily create new versions for testing.

# %%
def create_model():
    model = Sequential([  
        InputLayer(shape=(latitude, longitude, channels)),
        Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'),
        MaxPooling2D(pool_size = (2,2)),
        Dropout(.25),
        Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size = (2,2)),
        Dropout(.25),
        Flatten(),
        Dense(units = 100, activation = 'relu'),
        Dense(units = 100, activation = 'relu'),
        Dropout(.25),
        Dense(units = len(facet_list), activation = 'linear')
    ])
    return model

# %% [markdown]
# ##### Let's take a look at the whole thing:

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_33 (Conv2D)              │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_33 (MaxPooling2D) │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 9, 13, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_34 (MaxPooling2D) │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_39 (Dropout)            │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_40 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,678 (373.74 KB)
#  Trainable params: 95,614 (373.49 KB)
#  Non-trainable params: 64 (256.00 B)

# %% [markdown]
# ##### Our model has a little over 95,000 parameters or weights to train (hence the need for a lot of images). Note that there are small set of non-trainable parameter from the normalization layer.
#
# ##### We can also generate a simple visualization:

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# ##### The next step is to compile the model. This is an optimization function, a loss function and performance metric. A good option for the loss function in a regression problem is `mean_squared_error`, metrics allows the user to add aditional functions to monitor training. The optimizer implements the agorithmn which updates the weights of the model.

# %%
model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop())

# %% [markdown]
# ### Training the model
#
# ##### We'll now train the model for 50 epochs using the `fit()` method upon our built model. We specify:
#
# - `train_atmos`: The training subset of the atmospheric variables
# - `train_opg`: The training subset of the observed OPGs
# - `batch_size`: The number of samples or observation days used per gradient update.
# - `epochs`: The number of full training iterations.
# - `validation_data`: The validation subset of the atmospheric variables and observed OPGs
#
# ##### This takes a few minutes to train (on my laptop). It's worth remembering what is going on here: the algorithm is reading in batches of 32 images, rescaling them, updating model weights through back propagation and then repeating the whole thing 50 times. As we previously defined a separate validation subset, this routine will calculate two losses:
# - The training loss. This is how accurately the model can predict OPG from the atmospheric 'images' that are being used to update the weights
# - The validation loss. This is how accurately the model can predict OPG from a set of atmospheric 'images' that are not used in updating the weights
#
# ##### As the model continues to train, you should see the loss decrease for both of these, but will likely stabilize at a certain point.

# %%
epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7990 - mean_absolute_error: 0.5562 - val_loss: 0.4781 - val_mean_absolute_error: 0.3387
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4842 - mean_absolute_error: 0.3820 - val_loss: 0.4388 - val_mean_absolute_error: 0.3289
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4358 - mean_absolute_error: 0.3570 - val_loss: 0.4090 - val_mean_absolute_error: 0.3238
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3863 - mean_absolute_error: 0.3286 - val_loss: 0.3938 - val_mean_absolute_error: 0.3306
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3862 - mean_absolute_error: 0.3361 - val_loss: 0.4006 - val_mean_absolute_error: 0.3282
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3757 - mean_absolute_error: 0.3236 - val_loss: 0.3764 - val_mean_absolute_error: 0.3208
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3687 - mean_absolute_error: 0.3218 - val_loss: 0.3684 - val_mean_absolute_error: 0.3158
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3451 - mean_absolute_error: 0.3099 - val_loss: 0.3726 - val_mean_absolute_error: 0.3192
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3560 - mean_absolute_error: 0.3143 - val_loss: 0.3720 - val_mean_absolute_error: 0.3221
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3333 - mean_absolute_error: 0.3088 - val_loss: 0.3637 - val_mean_absolute_error: 0.3216
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3395 - mean_absolute_error: 0.3101 - val_loss: 0.3590 - val_mean_absolute_error: 0.3145
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3310 - mean_absolute_error: 0.3058 - val_loss: 0.3653 - val_mean_absolute_error: 0.3175
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3188 - mean_absolute_error: 0.3039 - val_loss: 0.3579 - val_mean_absolute_error: 0.3139
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3326 - mean_absolute_error: 0.3054 - val_loss: 0.3679 - val_mean_absolute_error: 0.3228
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3128 - mean_absolute_error: 0.2987 - val_loss: 0.3613 - val_mean_absolute_error: 0.3179
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3122 - mean_absolute_error: 0.2966 - val_loss: 0.3624 - val_mean_absolute_error: 0.3200
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3273 - mean_absolute_error: 0.3072 - val_loss: 0.3502 - val_mean_absolute_error: 0.3119
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3249 - mean_absolute_error: 0.3046 - val_loss: 0.3513 - val_mean_absolute_error: 0.3116
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3042 - mean_absolute_error: 0.2957 - val_loss: 0.3667 - val_mean_absolute_error: 0.3283
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2983 - mean_absolute_error: 0.2905 - val_loss: 0.3555 - val_mean_absolute_error: 0.3136
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2948 - mean_absolute_error: 0.2901 - val_loss: 0.3490 - val_mean_absolute_error: 0.3190
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3154 - mean_absolute_error: 0.2964 - val_loss: 0.3584 - val_mean_absolute_error: 0.3140
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2882 - mean_absolute_error: 0.2903 - val_loss: 0.3564 - val_mean_absolute_error: 0.3167
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2848 - mean_absolute_error: 0.2846 - val_loss: 0.3578 - val_mean_absolute_error: 0.3145
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3051 - mean_absolute_error: 0.2930 - val_loss: 0.3658 - val_mean_absolute_error: 0.3219
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2980 - mean_absolute_error: 0.2934 - val_loss: 0.3432 - val_mean_absolute_error: 0.3078
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2941 - mean_absolute_error: 0.2876 - val_loss: 0.3597 - val_mean_absolute_error: 0.3133
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2902 - mean_absolute_error: 0.2858 - val_loss: 0.3560 - val_mean_absolute_error: 0.3146
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2831 - mean_absolute_error: 0.2869 - val_loss: 0.3458 - val_mean_absolute_error: 0.3156
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2867 - mean_absolute_error: 0.2864 - val_loss: 0.3486 - val_mean_absolute_error: 0.3113
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2865 - mean_absolute_error: 0.2852 - val_loss: 0.3530 - val_mean_absolute_error: 0.3137
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3017 - mean_absolute_error: 0.2894 - val_loss: 0.3439 - val_mean_absolute_error: 0.3113
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2764 - mean_absolute_error: 0.2836 - val_loss: 0.3487 - val_mean_absolute_error: 0.3069
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2920 - mean_absolute_error: 0.2905 - val_loss: 0.3514 - val_mean_absolute_error: 0.3190
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2650 - mean_absolute_error: 0.2779 - val_loss: 0.3424 - val_mean_absolute_error: 0.3132
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2716 - mean_absolute_error: 0.2792 - val_loss: 0.3550 - val_mean_absolute_error: 0.3194
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2631 - mean_absolute_error: 0.2778 - val_loss: 0.3448 - val_mean_absolute_error: 0.3157
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2776 - mean_absolute_error: 0.2843 - val_loss: 0.3501 - val_mean_absolute_error: 0.3130
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2779 - mean_absolute_error: 0.2846 - val_loss: 0.3505 - val_mean_absolute_error: 0.3128
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2814 - mean_absolute_error: 0.2869 - val_loss: 0.3482 - val_mean_absolute_error: 0.3111
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2823 - mean_absolute_error: 0.2855 - val_loss: 0.3442 - val_mean_absolute_error: 0.3098
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2568 - mean_absolute_error: 0.2761 - val_loss: 0.3462 - val_mean_absolute_error: 0.3103
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2719 - mean_absolute_error: 0.2819 - val_loss: 0.3435 - val_mean_absolute_error: 0.3163
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2611 - mean_absolute_error: 0.2755 - val_loss: 0.3486 - val_mean_absolute_error: 0.3114
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2670 - mean_absolute_error: 0.2832 - val_loss: 0.3525 - val_mean_absolute_error: 0.3150
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2574 - mean_absolute_error: 0.2753 - val_loss: 0.3413 - val_mean_absolute_error: 0.3078
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2607 - mean_absolute_error: 0.2743 - val_loss: 0.3439 - val_mean_absolute_error: 0.3090
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2554 - mean_absolute_error: 0.2744 - val_loss: 0.3472 - val_mean_absolute_error: 0.3095
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2651 - mean_absolute_error: 0.2802 - val_loss: 0.3559 - val_mean_absolute_error: 0.3144
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2590 - mean_absolute_error: 0.2780 - val_loss: 0.3434 - val_mean_absolute_error: 0.3071
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2618 - mean_absolute_error: 0.2776 - val_loss: 0.3490 - val_mean_absolute_error: 0.3102
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2448 - mean_absolute_error: 0.2718 - val_loss: 0.3490 - val_mean_absolute_error: 0.3135
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2548 - mean_absolute_error: 0.2750 - val_loss: 0.3448 - val_mean_absolute_error: 0.3170
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2605 - mean_absolute_error: 0.2750 - val_loss: 0.3454 - val_mean_absolute_error: 0.3089
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2488 - mean_absolute_error: 0.2717 - val_loss: 0.3467 - val_mean_absolute_error: 0.3085
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2614 - mean_absolute_error: 0.2783 - val_loss: 0.3416 - val_mean_absolute_error: 0.3114
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2628 - mean_absolute_error: 0.2803 - val_loss: 0.3491 - val_mean_absolute_error: 0.3115
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2543 - mean_absolute_error: 0.2754 - val_loss: 0.3459 - val_mean_absolute_error: 0.3084
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2256 - mean_absolute_error: 0.2600 - val_loss: 0.3354 - val_mean_absolute_error: 0.3047
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2630 - mean_absolute_error: 0.2768 - val_loss: 0.3364 - val_mean_absolute_error: 0.3086
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2265 - mean_absolute_error: 0.2614 - val_loss: 0.3410 - val_mean_absolute_error: 0.3086
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2356 - mean_absolute_error: 0.2670 - val_loss: 0.3477 - val_mean_absolute_error: 0.3108
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2409 - mean_absolute_error: 0.2686 - val_loss: 0.3433 - val_mean_absolute_error: 0.3100
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2571 - mean_absolute_error: 0.2789 - val_loss: 0.3484 - val_mean_absolute_error: 0.3141
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2460 - mean_absolute_error: 0.2759 - val_loss: 0.3569 - val_mean_absolute_error: 0.3122
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2467 - mean_absolute_error: 0.2725 - val_loss: 0.3442 - val_mean_absolute_error: 0.3112
# Epoch 67/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2277 - mean_absolute_error: 0.2648 - val_loss: 0.3420 - val_mean_absolute_error: 0.3056
# Epoch 68/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2350 - mean_absolute_error: 0.2619 - val_loss: 0.3492 - val_mean_absolute_error: 0.3163
# Epoch 69/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2392 - mean_absolute_error: 0.2716 - val_loss: 0.3375 - val_mean_absolute_error: 0.3083
# Epoch 70/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2283 - mean_absolute_error: 0.2623 - val_loss: 0.3515 - val_mean_absolute_error: 0.3115
# Epoch 71/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2313 - mean_absolute_error: 0.2658 - val_loss: 0.3491 - val_mean_absolute_error: 0.3162
# Epoch 72/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2469 - mean_absolute_error: 0.2751 - val_loss: 0.3422 - val_mean_absolute_error: 0.3106
# Epoch 73/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2376 - mean_absolute_error: 0.2690 - val_loss: 0.3455 - val_mean_absolute_error: 0.3090
# Epoch 74/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2312 - mean_absolute_error: 0.2674 - val_loss: 0.3482 - val_mean_absolute_error: 0.3135
# Epoch 75/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2391 - mean_absolute_error: 0.2691 - val_loss: 0.3540 - val_mean_absolute_error: 0.3125
# Epoch 76/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2378 - mean_absolute_error: 0.2731 - val_loss: 0.3517 - val_mean_absolute_error: 0.3112
# Epoch 77/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2286 - mean_absolute_error: 0.2644 - val_loss: 0.3483 - val_mean_absolute_error: 0.3093
# Epoch 78/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2230 - mean_absolute_error: 0.2609 - val_loss: 0.3516 - val_mean_absolute_error: 0.3148
# Epoch 79/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2217 - mean_absolute_error: 0.2623 - val_loss: 0.3408 - val_mean_absolute_error: 0.3094
# Epoch 80/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2133 - mean_absolute_error: 0.2564 - val_loss: 0.3381 - val_mean_absolute_error: 0.3103

# %% [markdown]
# ##### Now plot the evolution of the loss function and the actual versus predicted OPGs:

# %%
def plot_loss(hist_obs):
    plt.plot(hist_obs.history['loss'], label='train')
    plt.plot(hist_obs.history['val_loss'], label='valid')
    plt.xlabel("Epochs")
    plt.ylabel("Mean Squared Error")
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()
    plt.show()

def plot_act_pred(modelx, hist_obs):
    # Using our fitted model, predict OPGs from the testing subset.
    predicted = modelx.predict(test_atmos)

    # set zero OPGs to nan
    actual = test_opg
    actual[actual==0] = np.nan
    predicted[predicted==0] = np.nan
    
    # Convert from standardized OPG to mm/m OPG
    actual    = (test_opg * opg_std) + opg_mean
    predicted = (predicted * opg_std) + opg_mean
    
    # Lets reshape our OPGs and remove NaN OPG days
    actual    = np.reshape(actual, -1)
    predicted = np.reshape(predicted, -1)
    idx       = np.isnan(actual) # Identify days with OPG observations
    actual    = actual[idx==False]
    predicted = predicted[idx==False]
    
    # Formulate the x and y axis limits
    max_val = np.max((np.max(predicted[:]), np.max(actual[:])))
    min_val = np.min((np.min(predicted[:]), np.min(actual[:])))
    max_val = 0.05
    min_val = -0.05
    
    # Define plot colormap
    cmap_gnuplot2 = ncm.cmap("MPL_gnuplot2")
    
    # Define label sizes
    label_size = 16
    tick_size = 14
    
    # Create Figure
    plt.figure(figsize=(6, 5))
    
    # Formulate the heatmap variables
    heatmap, xedges, yedges = np.histogram2d(np.reshape(actual, -1), np.reshape(predicted, -1), bins=100,
                                 range=[[min_val, max_val],[min_val, max_val]])
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

    # Plot heatmap
    plt.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap_gnuplot2, norm=colors.LogNorm())

    # Plot One-to-one line
    plt.plot([xedges[0], xedges[-1]], [yedges[0], yedges[-1]], c='red')

    # corr
    corr = np.round(np.corrcoef(actual, predicted)[0,1]**2 , 2)
    last_mse = np.round(hist_obs.history['val_loss'][-1], 2)
    
    # Add labels, gridlines, and colorbar
    plt.xlabel("Actual", fontsize=label_size)
    plt.ylabel("Predicted", fontsize=label_size)
    plt.title("r^2 = " + str(corr) + ", MSE = " + str(last_mse))
    plt.grid(True)
    plt.colorbar()


plot_loss(hist)
plot_act_pred(model, hist)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ##### The plot shows a steep decline in both loss values, but no real improvement beyond epoch 20. It's quite likely that this model has overfit - become too tuned to the training data to allow prediction. There are a variety of ways we can avoid this, but a simple one is to slow the rate at which the model learns. We'll refit the model, but will add a `learning_rate` parameter to the compilation step.
#
# ##### Additionally, `callbacks` can be added to the fitting process, in which the fit algorithm will monitor the validation loss. Here, when the validation loss does not improve after 5 epochs, the model stops training.

# %%
model = create_model()

model.compile(loss = 'mean_squared_error', 
              metrics = ["mean_absolute_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

epochs = 80
hist = model.fit(train_atmos, train_opg, # training data
                  batch_size = batch_size,
                  epochs = epochs,                        # epochs
                  validation_data = (val_atmos, val_opg), # validation data
                  callbacks=[callback],                   # patience
                  verbose = 1)                           # print progress
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.8282 - mean_absolute_error: 0.9466 - val_loss: 0.5196 - val_mean_absolute_error: 0.3755
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7128 - mean_absolute_error: 0.5703 - val_loss: 0.4992 - val_mean_absolute_error: 0.3589
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5808 - mean_absolute_error: 0.4781 - val_loss: 0.4890 - val_mean_absolute_error: 0.3524
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5075 - mean_absolute_error: 0.4213 - val_loss: 0.4753 - val_mean_absolute_error: 0.3504
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4657 - mean_absolute_error: 0.3943 - val_loss: 0.4602 - val_mean_absolute_error: 0.3514
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4694 - mean_absolute_error: 0.3841 - val_loss: 0.4482 - val_mean_absolute_error: 0.3499
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4400 - mean_absolute_error: 0.3700 - val_loss: 0.4403 - val_mean_absolute_error: 0.3475
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4468 - mean_absolute_error: 0.3685 - val_loss: 0.4313 - val_mean_absolute_error: 0.3473
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4568 - mean_absolute_error: 0.3673 - val_loss: 0.4264 - val_mean_absolute_error: 0.3431
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4014 - mean_absolute_error: 0.3476 - val_loss: 0.4220 - val_mean_absolute_error: 0.3426
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4116 - mean_absolute_error: 0.3515 - val_loss: 0.4187 - val_mean_absolute_error: 0.3434
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4074 - mean_absolute_error: 0.3467 - val_loss: 0.4125 - val_mean_absolute_error: 0.3400
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4147 - mean_absolute_error: 0.3480 - val_loss: 0.4088 - val_mean_absolute_error: 0.3328
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3919 - mean_absolute_error: 0.3402 - val_loss: 0.4047 - val_mean_absolute_error: 0.3364
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3891 - mean_absolute_error: 0.3372 - val_loss: 0.4047 - val_mean_absolute_error: 0.3308
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4235 - mean_absolute_error: 0.3463 - val_loss: 0.4021 - val_mean_absolute_error: 0.3332
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4002 - mean_absolute_error: 0.3388 - val_loss: 0.4013 - val_mean_absolute_error: 0.3353
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3852 - mean_absolute_error: 0.3314 - val_loss: 0.3995 - val_mean_absolute_error: 0.3300
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4028 - mean_absolute_error: 0.3391 - val_loss: 0.3958 - val_mean_absolute_error: 0.3314
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3933 - mean_absolute_error: 0.3397 - val_loss: 0.3980 - val_mean_absolute_error: 0.3321
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3649 - mean_absolute_error: 0.3236 - val_loss: 0.3956 - val_mean_absolute_error: 0.3313
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3725 - mean_absolute_error: 0.3260 - val_loss: 0.3943 - val_mean_absolute_error: 0.3292
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3994 - mean_absolute_error: 0.3349 - val_loss: 0.3923 - val_mean_absolute_error: 0.3287
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3924 - mean_absolute_error: 0.3362 - val_loss: 0.3913 - val_mean_absolute_error: 0.3287
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3546 - mean_absolute_error: 0.3195 - val_loss: 0.3891 - val_mean_absolute_error: 0.3277
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3869 - mean_absolute_error: 0.3335 - val_loss: 0.3874 - val_mean_absolute_error: 0.3289
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3680 - mean_absolute_error: 0.3263 - val_loss: 0.3862 - val_mean_absolute_error: 0.3274
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3551 - mean_absolute_error: 0.3227 - val_loss: 0.3860 - val_mean_absolute_error: 0.3266
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3790 - mean_absolute_error: 0.3281 - val_loss: 0.3839 - val_mean_absolute_error: 0.3250
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3588 - mean_absolute_error: 0.3206 - val_loss: 0.3821 - val_mean_absolute_error: 0.3249
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3668 - mean_absolute_error: 0.3265 - val_loss: 0.3820 - val_mean_absolute_error: 0.3262
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3595 - mean_absolute_error: 0.3258 - val_loss: 0.3807 - val_mean_absolute_error: 0.3282
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3620 - mean_absolute_error: 0.3199 - val_loss: 0.3786 - val_mean_absolute_error: 0.3242
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3686 - mean_absolute_error: 0.3276 - val_loss: 0.3783 - val_mean_absolute_error: 0.3271
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3532 - mean_absolute_error: 0.3191 - val_loss: 0.3781 - val_mean_absolute_error: 0.3264
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3996 - mean_absolute_error: 0.3384 - val_loss: 0.3762 - val_mean_absolute_error: 0.3248
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3750 - mean_absolute_error: 0.3268 - val_loss: 0.3758 - val_mean_absolute_error: 0.3238
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3525 - mean_absolute_error: 0.3179 - val_loss: 0.3742 - val_mean_absolute_error: 0.3244
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3733 - mean_absolute_error: 0.3256 - val_loss: 0.3735 - val_mean_absolute_error: 0.3251
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3515 - mean_absolute_error: 0.3199 - val_loss: 0.3728 - val_mean_absolute_error: 0.3260
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3646 - mean_absolute_error: 0.3269 - val_loss: 0.3712 - val_mean_absolute_error: 0.3249
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3563 - mean_absolute_error: 0.3202 - val_loss: 0.3692 - val_mean_absolute_error: 0.3245
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3380 - mean_absolute_error: 0.3176 - val_loss: 0.3683 - val_mean_absolute_error: 0.3236
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3563 - mean_absolute_error: 0.3238 - val_loss: 0.3705 - val_mean_absolute_error: 0.3236
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3588 - mean_absolute_error: 0.3229 - val_loss: 0.3699 - val_mean_absolute_error: 0.3261
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3447 - mean_absolute_error: 0.3210 - val_loss: 0.3685 - val_mean_absolute_error: 0.3247
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3618 - mean_absolute_error: 0.3244 - val_loss: 0.3684 - val_mean_absolute_error: 0.3221
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3477 - mean_absolute_error: 0.3191 - val_loss: 0.3666 - val_mean_absolute_error: 0.3220
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3479 - mean_absolute_error: 0.3179 - val_loss: 0.3666 - val_mean_absolute_error: 0.3220
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3574 - mean_absolute_error: 0.3201 - val_loss: 0.3667 - val_mean_absolute_error: 0.3209
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3629 - mean_absolute_error: 0.3252 - val_loss: 0.3669 - val_mean_absolute_error: 0.3211
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3427 - mean_absolute_error: 0.3165 - val_loss: 0.3659 - val_mean_absolute_error: 0.3224
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3580 - mean_absolute_error: 0.3201 - val_loss: 0.3657 - val_mean_absolute_error: 0.3225
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3467 - mean_absolute_error: 0.3185 - val_loss: 0.3654 - val_mean_absolute_error: 0.3223
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3269 - mean_absolute_error: 0.3112 - val_loss: 0.3636 - val_mean_absolute_error: 0.3232
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3323 - mean_absolute_error: 0.3124 - val_loss: 0.3653 - val_mean_absolute_error: 0.3232
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3476 - mean_absolute_error: 0.3193 - val_loss: 0.3649 - val_mean_absolute_error: 0.3214
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3476 - mean_absolute_error: 0.3169 - val_loss: 0.3658 - val_mean_absolute_error: 0.3233
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3349 - mean_absolute_error: 0.3147 - val_loss: 0.3650 - val_mean_absolute_error: 0.3243
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3577 - mean_absolute_error: 0.3257 - val_loss: 0.3633 - val_mean_absolute_error: 0.3224
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3439 - mean_absolute_error: 0.3162 - val_loss: 0.3637 - val_mean_absolute_error: 0.3217
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3035 - mean_absolute_error: 0.3017 - val_loss: 0.3648 - val_mean_absolute_error: 0.3237
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3343 - mean_absolute_error: 0.3131 - val_loss: 0.3656 - val_mean_absolute_error: 0.3221
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3520 - mean_absolute_error: 0.3165 - val_loss: 0.3653 - val_mean_absolute_error: 0.3229
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3224 - mean_absolute_error: 0.3096 - val_loss: 0.3646 - val_mean_absolute_error: 0.3243

# %%
plot_loss(hist)
plot_act_pred(model)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ##### The plot now shows a good evolution of the loss value.

# %% [markdown]
# ### Along with the loss function, the structure of the CNN can be changed. I suggest seeing what happens when you do the following:
# - `Change the Dense layers to have units=10`
# - `Uncomment the additional MaxPooling2D and Conv2D layers`
# - `Increase Conv2D filters to 64 and 128, respectively`
# - `Change the loss function to mean_absolute_error`
# - `Change the Dense layers to have activation="sigmoid"`
#
# ##### Pay mind to how changing these parameters affect the number of parameters to train, how long training time becomes, and the 2D histogram of actual versus predicted OPGs. Feel free to try your own edits to inspect how it affects the testing outcome.

# %%
model = Sequential([  
    InputLayer(shape=(latitude, longitude, channels)),
    Conv2D(filters = 16, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 16 to 64
    MaxPooling2D(pool_size = (2,2)),
    Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu'), # <-- Change the filter # from 32 to 128
    MaxPooling2D(pool_size = (2,2)),                                                    # <-- Comment in this line
    Conv2D(filters = 64, kernel_size = (3,3), padding = 'same', activation = 'relu'),   # <-- Comment in this line
    BatchNormalization(),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(.25),
    Flatten(),
    Dense(units = 100, activation = 'relu'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dense(units = 100, activation = 'relu'),  # <-- Change the units of the Dense Layers from 100 to 10
    Dropout(.25),
    Dense(units = len(facet_list), activation = 'linear') ])

model.summary()

model.compile(loss = 'mean_squared_error',          # <-- Change Loss Function Here from mean_squared_error to mean_absolute_error
              metrics = ["mean_absolute_error", "mean_squared_error"], 
              optimizer = RMSprop(learning_rate=1e-4))

epochs = 80

callback = [EarlyStopping(monitor='val_loss', patience=5, mode='min')]

hist = model.fit(train_atmos, train_opg, 
                  batch_size = batch_size,
                  epochs = epochs,                      
                  validation_data = (val_atmos, val_opg),
                  callbacks=[callback],
                  verbose = 0)                     # <-- If you want to silence training, set to 0, if you want to watch it train, set to 1

plot_loss(hist)
plot_act_pred(model)
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_37 (Conv2D)              │ (None, 19, 27, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_37 (MaxPooling2D) │ (None, 9, 13, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 9, 13, 32)      │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_38 (MaxPooling2D) │ (None, 4, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 4, 6, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 4, 6, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 2, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 2, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_17 (Flatten)            │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 100)            │        38,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 30)             │         3,030 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,902 (296.49 KB)
#  Trainable params: 75,774 (295.99 KB)
#  Non-trainable params: 128 (512.00 B)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ##### Notice the differences between outputs when changing the hyperparameters:
# - `Change the Dense layers to have units=10`:
#   The number of trainable parameters decreases considerably from 95,678 to 13,714. Though the mean squared error reaches a minimum around 80 epochs, the OPG heatmap shows the model is less able to predict more extreme OPGs. Too little parameters?
#
# - `Uncomment the additional MaxPooling2D and Conv2D layers`:
#   Additional MaxPooling2D and Conv2D layers decreased the number of trainable parameters from 95,614 to 75,774. Based on the mean squared error, the model seems to reach a minimum in error at around 55 epochs. The addition of MaxPooling2D and Conv2D layers did not visually improve the OPG predictions, but sped up training.
#
# - `Increase Conv2D filters to 64 and 128 respectively`:
#   Additional Conv2D filters significantly increased the number of trainable parameters from 95,614 to 398,062. Having more filters to identify patterns did not visually improve the mean squared error or the OPG predictions. It did increase the training time of the model, while decreasing the number of epochs. Indicating that more parameters does not mean a better model and can be unnessesary.
#
# - `Change the loss function to mean_absolute_error`:
#   Based on the plot of mean absolute error by epoch, the model tends to train very quickly in the beginning and trains slowly until around 80 epochs. The OPG heatmap shows OPGs are more underpredicted than when using mean_squared_error, most likely due to the loss function not focusing as hard on extreme errors.
#
# - `Change the Dense layers to have activation="sigmoid"`:
#
#
# ##### What you choose for hyperparameters and structure all depends on what your goals are.

# %%
# Using our fitted model, predict OPGs from the testing subset.
predicted = model.predict(test_atmos)

# Convert from standardized OPG to mm/m OPG
actual    = (test_opg * opg_std) + opg_mean
predicted = (predicted * opg_std) + opg_mean

# Since days without OPG observations are set to zero, lets reshape our OPGs and remove zero OPG days
actual    = np.reshape(actual, -1)
predicted = np.reshape(predicted, -1)
idx       = actual != 0.0 # Identify days with OPG observations
actual    = actual[idx]
predicted = predicted[idx]

# Formulate the x and y axis limits
max_val = np.max((np.max(predicted[:]), np.max(actual[:])))
min_val = np.min((np.min(predicted[:]), np.min(actual[:])))
max_val = 0.05
min_val = -0.05

# Define plot colormap
cmap_gnuplot2 = ncm.cmap("MPL_gnuplot2")

# Define label sizes
label_size = 16
tick_size = 14

# Create Figure
plt.figure(figsize=(6, 5))

# Formulate the heatmap variables
heatmap, xedges, yedges = np.histogram2d(np.reshape(actual, -1), np.reshape(predicted, -1), bins=100,
                             range=[[min_val, max_val],[min_val, max_val]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

# Plot heatmap
plt.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap_gnuplot2, norm=colors.LogNorm())

# Add labels, gridlines, and colorbar
plt.xlabel("Actual", fontsize=label_size)
plt.ylabel("Predicted", fontsize=label_size)
plt.grid(True)
plt.colorbar()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
